# %% [markdown]
# # EEG Epilepsy – All Channel Combinations × 4 Models
#
# Trains one of four model architectures for every possible subset of the 14 EEG channels.
#
# **Models available** (set `MODEL_NAME` in Cell 1):
# | Key | Architecture |
# |---|---|
# | `'CNN'` | 1-D CNN (5 Conv blocks → GAP → Dense) |
# | `'ChronoNet'` | 3 inception-style Conv blocks → 4 skip-connected GRUs |
# | `'CNN_LSTM'` | Deep CNN (Conv→Pool stack) → 2 LSTMs → Dense head |
# | `'IC_RNN'` | Inception Conv blocks → 4 plain GRUs (no skip connections) |
#
# **Structure**
# 1. Imports & Global Settings
# 2. Load Pre-extracted Features
# 3. Model Builders
# 4. Helper Functions
# 5. Main Training Loop
# 6. Save Metrics to Excel
# 7. Summary Plots

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/thesis_works
# Out:
# /content/drive/MyDrive/thesis_works

# %%
from google.colab import drive
import shutil
from google.colab import files

# %% [markdown]
# ## Cell 1 – Imports & Global Settings

# %%
# ── Standard library ────────────────────────────────────────────────────────
import os
import itertools
import random
import time
from itertools import combinations

# ── Numerical / data ────────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ── Plotting ────────────────────────────────────────────────────────────────
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt

# ── Scikit-learn ────────────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, cohen_kappa_score

# ── TensorFlow / Keras ──────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv1D, BatchNormalization, LeakyReLU,
    MaxPool1D, AveragePooling1D, GlobalAveragePooling1D,
    Dense, Dropout, LSTM, GRU, concatenate, Input,
)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import EarlyStopping
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  >>>  CHOOSE YOUR MODEL HERE  <<<                                       ║
# ║  Options: 'CNN'  |  'ChronoNet'  |  'CNN_LSTM'  |  'IC_RNN'            ║
# ╚══════════════════════════════════════════════════════════════════════════╝
MODEL_NAME = 'CNN_LSTM'      # <── change this

# ── Hyper-parameters ────────────────────────────────────────────────────────
EPOCHS      = 50
BATCH_SIZE  = 512
LR          = 0.0006
TEST_SIZE   = 0.2
RANDOM_SEED = 42

# ── Channel meta-data ───────────────────────────────────────────────────────
ALL_CHANNELS  = list(range(1, 15))   # 1-based indices
CHANNEL_NAMES = [
    'AF3','AF4','F3','F4','F7','F8',
    'FC5','FC6','O1','O2','P7','P8','T7','T8'
]

# ── Output root folder ──────────────────────────────────────────────────────
OUT_ROOT = f'outputs_{MODEL_NAME}'
os.makedirs(OUT_ROOT, exist_ok=True)

assert MODEL_NAME in ('CNN', 'ChronoNet', 'CNN_LSTM', 'IC_RNN'), \
    f"Unknown MODEL_NAME '{MODEL_NAME}'. Choose from: CNN, ChronoNet, CNN_LSTM, IC_RNN"

print('Setup complete.')
print(f'TensorFlow version : {tf.__version__}')
print(f'Selected model     : {MODEL_NAME}')
print(f'Output root        : {OUT_ROOT}/')
# Out:
# Setup complete.
# TensorFlow version : 2.20.0
# Selected model     : CNN_LSTM
# Output root        : outputs_CNN_LSTM/

# %% [markdown]
# ## Cell 2 – Load Pre-extracted Features

# %%
FEATURE_DIR    = 'nigeria_features'
FEATURE_PREFIX = 'features_Nigeria_channel_'
LABELS_FILE    = f'{FEATURE_DIR}/labels_groups_Nigeria.xlsx'

for its, j in enumerate(range(1, 15)):
    csv_path = f'{FEATURE_DIR}/{FEATURE_PREFIX}{j-1}.csv'
    df1 = pd.read_csv(csv_path, header=0, index_col=0).values   # (N, 640)
    if its == 0:
        df1a = df1[..., np.newaxis]
    else:
        df1a = np.concatenate((df1a, df1[..., np.newaxis]), axis=2)

print(f'Feature array shape : {df1a.shape}')   # (N, 640, 14)

df2 = pd.read_excel(LABELS_FILE, sheet_name='label_array',  header=0, index_col=0)
df3 = pd.read_excel(LABELS_FILE, sheet_name='group_array',  header=0, index_col=0)

print(f'Labels shape        : {df2.shape}')
print(f'Class balance:\n{df2.iloc[:,0].value_counts()}')
# Out:
# Feature array shape : (6127, 640, 14)
# Labels shape        : (6127, 1)
# Class balance:
# 0
# 1    3085
# 0    3042
# Name: count, dtype: int64

# %% [markdown]
# ## Cell 3 – Model Builders
#
# Each function accepts `n_channels` (number of EEG channels in the current
# subset) and `lr`, and returns a **compiled** Keras model.

# %%
# ────────────────────────────────────────────────────────────────────────────
# 1.  CNN  (original notebook architecture)
# ────────────────────────────────────────────────────────────────────────────

def build_CNN(n_channels: int, lr: float = LR) -> Sequential:
    clear_session()

    model = Sequential([
        tf.keras.Input(shape=(640, n_channels)),
        Conv1D(5, 3, strides=1, name='Conv1D_1'),
        BatchNormalization(name='BN_1'),
        LeakyReLU(name='LReLU_1'),
        MaxPool1D(2, 2, name='MaxPool_1'),

        Conv1D(5, 3, strides=1, name='Conv1D_2'),
        LeakyReLU(name='LReLU_2'),
        MaxPool1D(2, 2, name='MaxPool_2'),
        Dropout(0.2, name='Dropout_1'),

        Conv1D(5, 3, strides=1, name='Conv1D_3'),
        LeakyReLU(name='LReLU_3'),
        AveragePooling1D(2, 2, name='AvgPool_1'),
        Dropout(0.2, name='Dropout_2'),

        Conv1D(5, 3, strides=1, name='Conv1D_4'),
        LeakyReLU(name='LReLU_4'),
        AveragePooling1D(2, 2, name='AvgPool_2'),

        Conv1D(5, 3, strides=1, name='Conv1D_5'),
        LeakyReLU(name='LReLU_5'),

        GlobalAveragePooling1D(name='GAP'),
        Dense(1, activation='sigmoid', name='Output'),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )

    return model

# ────────────────────────────────────────────────────────────────────────────
# 2.  ChronoNet  (inception-style Conv blocks + skip-connected GRUs)
# ────────────────────────────────────────────────────────────────────────────
def build_ChronoNet(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    def _block(x, layer_no):
        c1 = Conv1D(32, 2, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_A_{layer_no}')(x)
        c2 = Conv1D(32, 4, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_B_{layer_no}')(x)
        c3 = Conv1D(32, 8, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_C_{layer_no}')(x)
        return concatenate([c1, c2, c3], axis=2, name=f'Concat_{layer_no}')

    inp    = Input(shape=(640, n_channels), name='InputLayer')
    b1     = _block(inp, 1)
    b2     = _block(b1,  2)
    b3     = _block(b2,  3)

    g1     = GRU(32, activation='tanh', return_sequences=True, name='GRU_1')(b3)
    g2     = GRU(32, activation='tanh', return_sequences=True, name='GRU_2')(g1)
    g2a    = concatenate([g1, g2], axis=2, name='Concat_4')
    g3     = GRU(32, activation='tanh', return_sequences=True, name='GRU_3')(g2a)
    g3a    = concatenate([g1, g2, g3], name='Concat_5')
    g4     = GRU(32, activation='tanh', name='GRU_4')(g3a)
    out    = Dense(1, activation='sigmoid', name='Output')(g4)

    model  = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ────────────────────────────────────────────────────────────────────────────
# 3.  CNN-LSTM  (deep CNN stack + 2 LSTM layers)
# ────────────────────────────────────────────────────────────────────────────
def build_CNN_LSTM(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    inp  = Input(shape=(640, n_channels), name='InputLayer')
    x    = Conv1D(64,   3, strides=1, activation='relu', padding='causal', name='Conv1D_1')(inp)
    x    = MaxPool1D(2, 2, name='MaxPool_1')(x)
    x    = Conv1D(128,  3, strides=1, activation='relu', padding='causal', name='Conv1D_2')(x)
    x    = Conv1D(512,  3, strides=1, activation='relu', padding='causal', name='Conv1D_3')(x)
    x    = Conv1D(1024, 3, strides=1, activation='relu', padding='causal', name='Conv1D_4')(x)
    x    = Dense(256, activation='relu', name='Dense_1')(x)
    x    = Dropout(0.5, name='Dropout_1')(x)
    x, *_= LSTM(64, return_sequences=True, return_state=True, name='LSTM_1')(x)
    x    = LSTM(64, name='LSTM_2')(x)
    x    = Dense(256, activation='relu', name='Dense_2')(x)
    x    = Dense(128, activation='relu', name='Dense_3')(x)
    x    = Dense(64,  activation='relu', name='Dense_4')(x)
    out  = Dense(1, activation='sigmoid', name='Output')(x)

    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ────────────────────────────────────────────────────────────────────────────
# 4.  IC-RNN  (inception Conv blocks + 4 plain GRUs, no skip connections)
# ────────────────────────────────────────────────────────────────────────────
def build_IC_RNN(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    def _block(x, layer_no):
        c1 = Conv1D(32, 2, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_A_{layer_no}')(x)
        c2 = Conv1D(32, 4, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_B_{layer_no}')(x)
        c3 = Conv1D(32, 8, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_C_{layer_no}')(x)
        return concatenate([c1, c2, c3], axis=2, name=f'Concat_{layer_no}')

    inp = Input(shape=(640, n_channels), name='InputLayer')
    b1  = _block(inp, 1)
    b2  = _block(b1,  2)
    b3  = _block(b2,  3)

    g1  = GRU(32, activation='tanh', return_sequences=True, name='GRU_1')(b3)
    g2  = GRU(32, activation='tanh', return_sequences=True, name='GRU_2')(g1)
    g3  = GRU(32, activation='tanh', return_sequences=True, name='GRU_3')(g2)
    g4  = GRU(32, activation='tanh', name='GRU_4')(g3)
    out = Dense(1, activation='sigmoid', name='Output')(g4)

    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ── Dispatch table ───────────────────────────────────────────────────────────
_BUILDERS = {
    'CNN':       build_CNN,
    'ChronoNet': build_ChronoNet,
    'CNN_LSTM':  build_CNN_LSTM,
    'IC_RNN':    build_IC_RNN,
}

def build_model(n_channels: int, lr: float = LR) -> Model:
    """Build and return the model selected by MODEL_NAME."""
    return _BUILDERS[MODEL_NAME](n_channels, lr)


print('Model builders defined.')
print(f'Active builder     : build_{MODEL_NAME}()')
# Out:
# Model builders defined.
# Active builder     : build_CNN_LSTM()

# %% [markdown]
# ## Cell 4 – Helper Functions

# %%
# ────────────────────────────────────────────────────────────────────────────
# Reproducibility
# ────────────────────────────────────────────────────────────────────────────
def reset_seeds(seed: int = 42) -> None:
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()


# ────────────────────────────────────────────────────────────────────────────
# Label helpers
# ────────────────────────────────────────────────────────────────────────────
def make_combo_label(kept_indices: list, n_total: int = 14) -> dict:
    kept_names    = [CHANNEL_NAMES[i-1] for i in kept_indices]
    dropped_idx   = [j for j in ALL_CHANNELS if j not in kept_indices]
    dropped_names = [CHANNEL_NAMES[j-1] for j in dropped_idx]
    n_keep = len(kept_indices)
    n_drop = len(dropped_idx)

    if n_drop == 0:
        title = 'All 14 channels'
    elif n_keep >= 8:
        title = f'Dropped: {", ".join(dropped_names)}'
    else:
        title = f'Kept: {", ".join(kept_names)}'

    drop_str = '_'.join(dropped_names) if dropped_names else 'none'
    fname    = f'keep{n_keep:02d}_drop_{drop_str}'

    return {
        'title': title, 'fname': fname,
        'n_keep': n_keep, 'n_drop': n_drop,
        'kept_names': kept_names, 'dropped_names': dropped_names,
    }


# ────────────────────────────────────────────────────────────────────────────
# Per-combination figure saver
# ────────────────────────────────────────────────────────────────────────────
def save_figures_for_combo(history, y_test, y_pred,
                            label_info: dict, out_dir: str) -> dict:
    os.makedirs(out_dir, exist_ok=True)
    title  = label_info['title']
    fname  = label_info['fname']
    fw, fs = 'bold', 12

    y_pred_bin  = np.round(y_pred).astype(int).squeeze()
    cm          = confusion_matrix(y_test, y_pred_bin)
    cm_norm     = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    auc         = roc_auc_score(y_test, y_pred)
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    cks         = cohen_kappa_score(y_test, y_pred_bin)

    tn, fp, fn, tp = cm.ravel()
    precision = 100 * tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = 100 * tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1        = 2 * precision * recall / (precision + recall) \
                if (precision + recall) > 0 else 0.0

    #getting the best val_acc due to callback
    best_epoch = np.argmax(history.history['val_accuracy'])

    val_acc  = history.history['val_accuracy'][best_epoch] * 100
    val_loss = history.history['val_loss'][best_epoch]



    # 1. Accuracy curve
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(history.history['accuracy'],     color='#00ABCD', label='Train')
    ax.plot(history.history['val_accuracy'], color='#121212', label='Test')
    ax.set_title(f'Accuracy – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Epoch', fontweight=fw, fontsize=fs)
    ax.set_ylabel('Accuracy', fontweight=fw, fontsize=fs)
    ax.set_xlim(0, EPOCHS); ax.set_ylim(0, 1)
    ax.set_xticks(np.arange(0, EPOCHS + 1, 20))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_accuracy_curve.png'), dpi=150)
    plt.close(fig)

    # 2. Loss curve
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(history.history['loss'],     color='#00ABCD', label='Train')
    ax.plot(history.history['val_loss'], color='#121212', label='Test')
    ax.set_title(f'Loss – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Epoch', fontweight=fw, fontsize=fs)
    ax.set_ylabel('Binary Cross-entropy', fontweight=fw, fontsize=fs)
    ax.set_xlim(0, EPOCHS); ax.set_ylim(0, 1)
    ax.set_xticks(np.arange(0, EPOCHS + 1, 20))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_loss_curve.png'), dpi=150)
    plt.close(fig)

    # 3. Confusion Matrix
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.matshow(cm, cmap=plt.cm.binary)
    threshold = (cm.max() + cm.min()) / 2.0
    for i_cm, j_cm in itertools.product(range(2), range(2)):
        ax.text(j_cm, i_cm, f'{cm_norm[i_cm, j_cm]*100:.1f}%',
                ha='center', va='center',
                color='white' if cm[i_cm, j_cm] > threshold else 'black',
                fontweight=fw, fontsize=fs)
    ax.set_title(f'Confusion Matrix\n{title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Predicted Label', fontweight=fw, fontsize=fs)
    ax.set_ylabel('True Label', fontweight=fw, fontsize=fs)
    ax.set_xticks([0, 1]); ax.set_yticks([0, 1])
    ax.xaxis.set_label_position('bottom'); ax.xaxis.tick_bottom()
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_confusion_matrix.png'), dpi=150)
    plt.close(fig)

    # 4. ROC curve
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.plot(fpr, tpr, color='#000000', label=f'AUC = {auc:.3f}')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=0.8)
    ax.set_title(f'ROC – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('False Positive Rate', fontweight=fw, fontsize=fs)
    ax.set_ylabel('True Positive Rate', fontweight=fw, fontsize=fs)
    ax.set_xticks(np.linspace(0, 1, 3)); ax.set_yticks(np.linspace(0, 1, 3))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_roc_curve.png'), dpi=150)
    plt.close(fig)

    return {
        'model':     MODEL_NAME,
        'title':     title,
        'fname':     fname,
        'n_keep':    label_info['n_keep'],
        'kept':      ', '.join(label_info['kept_names']),
        'dropped':   ', '.join(label_info['dropped_names']) or 'none',
        'val_acc':   val_acc,
        'val_loss':  val_loss,
        'auc':       auc,
        'precision': precision,
        'recall':    recall,
        'f1':        f1,
        'cohen_kappa': cks,
        'tn': tn, 'fp': fp, 'fn': fn, 'tp': tp,
    }


print('Helper functions defined.')
# Out:
# Helper functions defined.

# %% [markdown]
# ## Cell 5 – Main Training Loop
#
# Iterates over every non-empty subset of the 14 channels (2^14 − 1 = 16 383).
#
# > Set `MAX_COMBOS = None` to run all combinations.

# %%
MAX_COMBOS = None     # set to None for a full run

all_results   = []
combo_counter = 0

for n_exclude in range(2,3):                  #(0,14)
    n_keep = 14 - n_exclude

    for excl in combinations(ALL_CHANNELS, n_exclude):

        if MAX_COMBOS is not None and combo_counter >= MAX_COMBOS:
            print(f'Reached MAX_COMBOS = {MAX_COMBOS}. Stopping.')
            break

        my_list    = [j for j in ALL_CHANNELS if j not in excl]
        label_info = make_combo_label(my_list)
        combo_counter += 1

        print(f'[{combo_counter:5d}] model={MODEL_NAME} | keep={n_keep:2d} | {label_info["title"]}',
              flush=True)

        combo_dir = os.path.join(OUT_ROOT, f'keep{n_keep:02d}', label_info['fname'])
        os.makedirs(combo_dir, exist_ok=True)

        # ── Prepare data ────────────────────────────────────────────────────
        data_array  = df1a[..., np.array(my_list) - 1]   # (N, 640, n_keep)
        label_array = df2.iloc[:, 0].values

        X_train, X_test, y_train, y_test = train_test_split(
            data_array, label_array,
            test_size=TEST_SIZE, random_state=RANDOM_SEED, stratify=label_array,
        )

        sc      = StandardScaler()
        X_train = sc.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
        X_test  = sc.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

        # ── Build & train ────────────────────────────────────────────────────
        reset_seeds(RANDOM_SEED)
        model = build_model(n_channels=n_keep, lr=LR)

        t0      = time.time()

         # moving it near fit(), the goal was to ensure a fresh callback is created for every iteration:
        early_stop = tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=7,
            restore_best_weights=True,
            verbose=1,
            mode='max'
        )
        history = model.fit(
            tf.constant(X_train), tf.constant(y_train),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(tf.constant(X_test), y_test),
            callbacks=[early_stop],
            verbose=1
        )
        train_time = time.time() - t0

        # ── Evaluate ─────────────────────────────────────────────────────────
        y_pred = model.predict(X_test, verbose=0)

        # ── Save figures & collect metrics ────────────────────────────────────
        metrics = save_figures_for_combo(
            history=history,
            y_test=y_test,
            y_pred=y_pred,
            label_info=label_info,
            out_dir=combo_dir,
        )
        metrics['train_time_s'] = round(train_time, 1)

        # ── Save training history CSV ─────────────────────────────────────────
        pd.DataFrame(history.history).to_csv(
            os.path.join(combo_dir, f'{label_info["fname"]}_history.csv'),
            index_label='epoch',
        )

        all_results.append(metrics)
        print(f'        val_acc={metrics["val_acc"]:.1f}%  '
              f'AUC={metrics["auc"]:.3f}  '
              f'F1={metrics["f1"]:.1f}%  '
              f'κ={metrics["cohen_kappa"]:.3f}  '
              f't={train_time:.0f}s',
              flush=True)

    else:
        continue
    break

print(f'\nDone. Combinations run: {combo_counter}')
# Out:
# [    1] model=CNN_LSTM | keep=12 | Dropped: AF3, AF4
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 888ms/step - accuracy: 0.5260 - loss: 0.6906 - val_accuracy: 0.5408 - val_loss: 0.6860
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.5862 - loss: 0.6763 - val_accuracy: 0.5351 - val_loss: 0.6970
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 874ms/step - accuracy: 0.6089 - loss: 0.6627 - val_accuracy: 0.6501 - val_loss: 0.6521
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 859ms/step - accuracy: 0.6527 - loss: 0.6339 - val_accuracy: 0.5644 - val_loss: 0.6796
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 0.6756 - loss: 0.6105 - val_accuracy: 0.6990 - val_loss: 0.5947
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 872ms/step - accuracy: 0.7323 - loss: 0.5475 - val_accuracy: 0.7520 - val_loss: 0.5399
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.7564 - loss: 0.5315 - val_accuracy: 0.6754 - val_loss: 0.6208
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.7339 - loss: 0.5531 - val_accuracy: 0.7333 - val_loss: 0.6080
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 768ms/step - accuracy: 0.6956 - loss: 0.6148 - val_accuracy: 0.7023 - val_loss: 0.6021
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 776ms/step - accuracy: 0.7137 - loss: 0.5810 - val_accuracy: 0.6941 - val_loss: 0.6066
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7245 - loss: 0.5623 - val_accuracy: 0.7129 - val_loss: 0.5683
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7486 - loss: 0.5321 - val_accuracy: 0.7529 - val_loss: 0.5283
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 869ms/step - accuracy: 0.7894 - loss: 0.4728 - val_accuracy: 0.7732 - val_loss: 0.4972
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step - accuracy: 0.7417 - loss: 0.5408 - val_accuracy: 0.7863 - val_loss: 0.4916
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.7664 - loss: 0.5241 - val_accuracy: 0.7993 - val_loss: 0.4811
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7713 - loss: 0.5155 - val_accuracy: 0.6591 - val_loss: 0.6699
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 785ms/step - accuracy: 0.7380 - loss: 0.5649 - val_accuracy: 0.7349 - val_loss: 0.5636
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7519 - loss: 0.5304 - val_accuracy: 0.7170 - val_loss: 0.5881
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7758 - loss: 0.4886 - val_accuracy: 0.7594 - val_loss: 0.5302
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.7996 - loss: 0.4635 - val_accuracy: 0.7651 - val_loss: 0.5275
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8070 - loss: 0.4554 - val_accuracy: 0.8042 - val_loss: 0.4719
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.7437 - loss: 0.5183 - val_accuracy: 0.6713 - val_loss: 0.6200
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 769ms/step - accuracy: 0.6990 - loss: 0.6394 - val_accuracy: 0.7423 - val_loss: 0.5487
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 768ms/step - accuracy: 0.7558 - loss: 0.5425 - val_accuracy: 0.7382 - val_loss: 0.5609
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 0.7460 - loss: 0.5442 - val_accuracy: 0.7455 - val_loss: 0.5485
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 766ms/step - accuracy: 0.7323 - loss: 0.5869 - val_accuracy: 0.6493 - val_loss: 0.6480
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step - accuracy: 0.7027 - loss: 0.5918 - val_accuracy: 0.6843 - val_loss: 0.5858
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 766ms/step - accuracy: 0.6493 - loss: 0.5974 - val_accuracy: 0.7007 - val_loss: 0.5743
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.
#         val_acc=80.4%  AUC=0.853  F1=82.3%  κ=0.608  t=229s
# [    2] model=CNN_LSTM | keep=12 | Dropped: AF3, F3
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 877ms/step - accuracy: 0.5142 - loss: 0.6914 - val_accuracy: 0.5220 - val_loss: 0.6887
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 818ms/step - accuracy: 0.5558 - loss: 0.6838 - val_accuracy: 0.6142 - val_loss: 0.6757
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step - accuracy: 0.5903 - loss: 0.6717 - val_accuracy: 0.6256 - val_loss: 0.6684
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step - accuracy: 0.6378 - loss: 0.6495 - val_accuracy: 0.6485 - val_loss: 0.6412
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step - accuracy: 0.6786 - loss: 0.6129 - val_accuracy: 0.7104 - val_loss: 0.5709
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step - accuracy: 0.6976 - loss: 0.5865 - val_accuracy: 0.6721 - val_loss: 0.6144
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7007 - loss: 0.5895 - val_accuracy: 0.7153 - val_loss: 0.5676
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7670 - loss: 0.5100 - val_accuracy: 0.5555 - val_loss: 0.7994
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 774ms/step - accuracy: 0.5358 - loss: 0.7124 - val_accuracy: 0.5228 - val_loss: 0.6879
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.5315 - loss: 0.6837 - val_accuracy: 0.5914 - val_loss: 0.6740
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.6327 - loss: 0.6550 - val_accuracy: 0.6542 - val_loss: 0.6392
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.6839 - loss: 0.6081 - val_accuracy: 0.6941 - val_loss: 0.5941
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 869ms/step - accuracy: 0.7225 - loss: 0.5616 - val_accuracy: 0.7586 - val_loss: 0.5258
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 797ms/step - accuracy: 0.7603 - loss: 0.5248 - val_accuracy: 0.6762 - val_loss: 0.6299
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.6566 - loss: 0.6394 - val_accuracy: 0.5742 - val_loss: 0.6611
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.5831 - loss: 0.6640 - val_accuracy: 0.5326 - val_loss: 0.6814
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.5774 - loss: 0.6714 - val_accuracy: 0.6444 - val_loss: 0.6511
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.6599 - loss: 0.6299 - val_accuracy: 0.7137 - val_loss: 0.5924
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7174 - loss: 0.5777 - val_accuracy: 0.5783 - val_loss: 0.6947
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 854ms/step - accuracy: 0.7174 - loss: 0.5769 - val_accuracy: 0.7545 - val_loss: 0.5408
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 13.
#         val_acc=75.9%  AUC=0.816  F1=75.6%  κ=0.517  t=165s
# [    3] model=CNN_LSTM | keep=12 | Dropped: AF3, F4
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 843ms/step - accuracy: 0.5179 - loss: 0.6920 - val_accuracy: 0.5171 - val_loss: 0.6888
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 813ms/step - accuracy: 0.5611 - loss: 0.6808 - val_accuracy: 0.5449 - val_loss: 0.6910
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step - accuracy: 0.6042 - loss: 0.6643 - val_accuracy: 0.6468 - val_loss: 0.6503
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step - accuracy: 0.6366 - loss: 0.6551 - val_accuracy: 0.5865 - val_loss: 0.6734
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 808ms/step - accuracy: 0.6301 - loss: 0.6449 - val_accuracy: 0.6737 - val_loss: 0.6294
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 803ms/step - accuracy: 0.6739 - loss: 0.6117 - val_accuracy: 0.6966 - val_loss: 0.6041
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7158 - loss: 0.5774 - val_accuracy: 0.7292 - val_loss: 0.5580
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7529 - loss: 0.5313 - val_accuracy: 0.7708 - val_loss: 0.5246
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7621 - loss: 0.5262 - val_accuracy: 0.7659 - val_loss: 0.5238
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 774ms/step - accuracy: 0.7743 - loss: 0.4982 - val_accuracy: 0.7904 - val_loss: 0.4971
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7860 - loss: 0.4814 - val_accuracy: 0.7781 - val_loss: 0.4822
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.8021 - loss: 0.4625 - val_accuracy: 0.7031 - val_loss: 0.6378
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7237 - loss: 0.5922 - val_accuracy: 0.6354 - val_loss: 0.6495
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6911 - loss: 0.6165 - val_accuracy: 0.6974 - val_loss: 0.6073
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 785ms/step - accuracy: 0.7531 - loss: 0.5397 - val_accuracy: 0.7349 - val_loss: 0.5793
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6670 - loss: 0.6298 - val_accuracy: 0.7259 - val_loss: 0.5938
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7231 - loss: 0.5742 - val_accuracy: 0.6900 - val_loss: 0.5778
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#         val_acc=79.0%  AUC=0.844  F1=78.8%  κ=0.581  t=141s
# [    4] model=CNN_LSTM | keep=12 | Dropped: AF3, F7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 862ms/step - accuracy: 0.5007 - loss: 0.6922 - val_accuracy: 0.5228 - val_loss: 0.6901
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step - accuracy: 0.5595 - loss: 0.6841 - val_accuracy: 0.5856 - val_loss: 0.6797
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step - accuracy: 0.5997 - loss: 0.6699 - val_accuracy: 0.5946 - val_loss: 0.6689
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step - accuracy: 0.6309 - loss: 0.6474 - val_accuracy: 0.6582 - val_loss: 0.6369
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 0.6717 - loss: 0.6180 - val_accuracy: 0.7031 - val_loss: 0.6013
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 804ms/step - accuracy: 0.7135 - loss: 0.5725 - val_accuracy: 0.6199 - val_loss: 0.6893
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.7352 - loss: 0.5447 - val_accuracy: 0.7382 - val_loss: 0.5262
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 845ms/step - accuracy: 0.5591 - loss: 0.8255 - val_accuracy: 0.5277 - val_loss: 0.6928
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 761ms/step - accuracy: 0.5050 - loss: 0.6953 - val_accuracy: 0.4959 - val_loss: 0.6933
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 766ms/step - accuracy: 0.5103 - loss: 0.6927 - val_accuracy: 0.5383 - val_loss: 0.6922
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 763ms/step - accuracy: 0.5225 - loss: 0.6918 - val_accuracy: 0.5334 - val_loss: 0.6918
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.5511 - loss: 0.6892 - val_accuracy: 0.5563 - val_loss: 0.6896
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 843ms/step - accuracy: 0.5762 - loss: 0.6810 - val_accuracy: 0.5710 - val_loss: 0.6892
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.6031 - loss: 0.6663 - val_accuracy: 0.6183 - val_loss: 0.6590
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
#         val_acc=73.8%  AUC=0.820  F1=77.6%  κ=0.475  t=120s
# [    5] model=CNN_LSTM | keep=12 | Dropped: AF3, F8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 889ms/step - accuracy: 0.5136 - loss: 0.6912 - val_accuracy: 0.5310 - val_loss: 0.6894
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 830ms/step - accuracy: 0.5729 - loss: 0.6786 - val_accuracy: 0.6077 - val_loss: 0.6760
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 860ms/step - accuracy: 0.6297 - loss: 0.6512 - val_accuracy: 0.6615 - val_loss: 0.6327
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 838ms/step - accuracy: 0.6613 - loss: 0.6221 - val_accuracy: 0.6729 - val_loss: 0.6124
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.6886 - loss: 0.5887 - val_accuracy: 0.6069 - val_loss: 0.6704
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 873ms/step - accuracy: 0.6884 - loss: 0.5925 - val_accuracy: 0.7039 - val_loss: 0.5847
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7262 - loss: 0.5409 - val_accuracy: 0.7357 - val_loss: 0.5282
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.7292 - loss: 0.5680 - val_accuracy: 0.6705 - val_loss: 0.6617
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6844 - loss: 0.6127 - val_accuracy: 0.6884 - val_loss: 0.6165
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7182 - loss: 0.5744 - val_accuracy: 0.7284 - val_loss: 0.5666
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7496 - loss: 0.5207 - val_accuracy: 0.7618 - val_loss: 0.5019
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step - accuracy: 0.7841 - loss: 0.4766 - val_accuracy: 0.7610 - val_loss: 0.5717
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step - accuracy: 0.7678 - loss: 0.5110 - val_accuracy: 0.7390 - val_loss: 0.5341
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7582 - loss: 0.5094 - val_accuracy: 0.7749 - val_loss: 0.5135
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 797ms/step - accuracy: 0.7768 - loss: 0.4920 - val_accuracy: 0.5302 - val_loss: 1.1126
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.5185 - loss: 0.8383 - val_accuracy: 0.5734 - val_loss: 0.6760
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step - accuracy: 0.5291 - loss: 0.6571 - val_accuracy: 0.6044 - val_loss: 0.6750
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 0.6097 - loss: 0.6450 - val_accuracy: 0.6607 - val_loss: 0.7115
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 765ms/step - accuracy: 0.6360 - loss: 0.6774 - val_accuracy: 0.5889 - val_loss: 0.6728
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 769ms/step - accuracy: 0.6378 - loss: 0.6536 - val_accuracy: 0.6697 - val_loss: 0.6253
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 765ms/step - accuracy: 0.5787 - loss: 0.7032 - val_accuracy: 0.5179 - val_loss: 0.7019
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
#         val_acc=77.5%  AUC=0.832  F1=80.3%  κ=0.549  t=173s
# [    6] model=CNN_LSTM | keep=12 | Dropped: AF3, FC5
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 872ms/step - accuracy: 0.5044 - loss: 0.6912 - val_accuracy: 0.5073 - val_loss: 0.6929
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.5642 - loss: 0.6820 - val_accuracy: 0.5889 - val_loss: 0.6809
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 851ms/step - accuracy: 0.6007 - loss: 0.6621 - val_accuracy: 0.5840 - val_loss: 0.6746
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 845ms/step - accuracy: 0.6411 - loss: 0.6381 - val_accuracy: 0.6411 - val_loss: 0.6333
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 0.6760 - loss: 0.6099 - val_accuracy: 0.7015 - val_loss: 0.5884
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 806ms/step - accuracy: 0.7145 - loss: 0.5788 - val_accuracy: 0.6599 - val_loss: 0.6204
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7274 - loss: 0.5587 - val_accuracy: 0.7488 - val_loss: 0.5332
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7676 - loss: 0.5121 - val_accuracy: 0.7781 - val_loss: 0.4924
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7947 - loss: 0.4718 - val_accuracy: 0.7904 - val_loss: 0.4773
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.8098 - loss: 0.4482 - val_accuracy: 0.8165 - val_loss: 0.4291
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.8292 - loss: 0.4122 - val_accuracy: 0.8051 - val_loss: 0.4369
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.8366 - loss: 0.3928 - val_accuracy: 0.8214 - val_loss: 0.4202
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 856ms/step - accuracy: 0.8090 - loss: 0.4401 - val_accuracy: 0.7512 - val_loss: 0.4857
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.8194 - loss: 0.4261 - val_accuracy: 0.7985 - val_loss: 0.4612
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7594 - loss: 0.5056 - val_accuracy: 0.7928 - val_loss: 0.4939
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 797ms/step - accuracy: 0.8225 - loss: 0.4235 - val_accuracy: 0.8002 - val_loss: 0.4752
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.8404 - loss: 0.3804 - val_accuracy: 0.8230 - val_loss: 0.4237
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.8515 - loss: 0.3612 - val_accuracy: 0.8361 - val_loss: 0.4049
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.8808 - loss: 0.3137 - val_accuracy: 0.8254 - val_loss: 0.4411
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 785ms/step - accuracy: 0.8831 - loss: 0.3074 - val_accuracy: 0.8458 - val_loss: 0.3858
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.8780 - loss: 0.3034 - val_accuracy: 0.8442 - val_loss: 0.3648
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8892 - loss: 0.2781 - val_accuracy: 0.8524 - val_loss: 0.3683
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 776ms/step - accuracy: 0.9086 - loss: 0.2317 - val_accuracy: 0.8630 - val_loss: 0.3726
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.9151 - loss: 0.2209 - val_accuracy: 0.8605 - val_loss: 0.3857
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.9119 - loss: 0.2250 - val_accuracy: 0.7945 - val_loss: 0.6049
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8888 - loss: 0.2987 - val_accuracy: 0.8320 - val_loss: 0.4528
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.8684 - loss: 0.3214 - val_accuracy: 0.8173 - val_loss: 0.4176
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.8713 - loss: 0.3055 - val_accuracy: 0.8573 - val_loss: 0.3971
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.9180 - loss: 0.2173 - val_accuracy: 0.8426 - val_loss: 0.3630
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9194 - loss: 0.2064 - val_accuracy: 0.8540 - val_loss: 0.3396
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
#         val_acc=86.3%  AUC=0.933  F1=86.7%  κ=0.726  t=245s
# [    7] model=CNN_LSTM | keep=12 | Dropped: AF3, FC6
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 940ms/step - accuracy: 0.5168 - loss: 0.6911 - val_accuracy: 0.5514 - val_loss: 0.6901
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step - accuracy: 0.5762 - loss: 0.6795 - val_accuracy: 0.5808 - val_loss: 0.6835
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step - accuracy: 0.5897 - loss: 0.6682 - val_accuracy: 0.5987 - val_loss: 0.6706
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 905ms/step - accuracy: 0.6352 - loss: 0.6457 - val_accuracy: 0.6191 - val_loss: 0.6608
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step - accuracy: 0.6676 - loss: 0.6154 - val_accuracy: 0.6631 - val_loss: 0.6146
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 802ms/step - accuracy: 0.7009 - loss: 0.5842 - val_accuracy: 0.6900 - val_loss: 0.5998
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7039 - loss: 0.5791 - val_accuracy: 0.7219 - val_loss: 0.5740
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7190 - loss: 0.5630 - val_accuracy: 0.6281 - val_loss: 0.6953
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.6897 - loss: 0.5916 - val_accuracy: 0.6639 - val_loss: 0.6031
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7452 - loss: 0.5277 - val_accuracy: 0.7447 - val_loss: 0.5391
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 865ms/step - accuracy: 0.6333 - loss: 0.7940 - val_accuracy: 0.5033 - val_loss: 0.7665
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.4983 - loss: 0.7077 - val_accuracy: 0.5033 - val_loss: 0.6917
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.5162 - loss: 0.6908 - val_accuracy: 0.5294 - val_loss: 0.6888
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.5634 - loss: 0.6815 - val_accuracy: 0.5767 - val_loss: 0.6814
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.5787 - loss: 0.6736 - val_accuracy: 0.5840 - val_loss: 0.6777
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 844ms/step - accuracy: 0.5887 - loss: 0.6686 - val_accuracy: 0.5897 - val_loss: 0.6714
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step - accuracy: 0.6042 - loss: 0.6621 - val_accuracy: 0.5930 - val_loss: 0.6812
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#         val_acc=74.5%  AUC=0.808  F1=72.6%  κ=0.490  t=143s
# [    8] model=CNN_LSTM | keep=12 | Dropped: AF3, O1
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 846ms/step - accuracy: 0.5160 - loss: 0.6909 - val_accuracy: 0.5489 - val_loss: 0.6881
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.5699 - loss: 0.6794 - val_accuracy: 0.5922 - val_loss: 0.6788
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 857ms/step - accuracy: 0.6133 - loss: 0.6606 - val_accuracy: 0.6240 - val_loss: 0.6574
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 850ms/step - accuracy: 0.6507 - loss: 0.6335 - val_accuracy: 0.6215 - val_loss: 0.6462
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 831ms/step - accuracy: 0.6758 - loss: 0.6112 - val_accuracy: 0.6925 - val_loss: 0.6022
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 804ms/step - accuracy: 0.7031 - loss: 0.5826 - val_accuracy: 0.7251 - val_loss: 0.5640
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 864ms/step - accuracy: 0.7584 - loss: 0.5170 - val_accuracy: 0.7928 - val_loss: 0.4900
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step - accuracy: 0.6870 - loss: 0.6172 - val_accuracy: 0.6387 - val_loss: 0.6426
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 769ms/step - accuracy: 0.6907 - loss: 0.6083 - val_accuracy: 0.6786 - val_loss: 0.6119
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.6911 - loss: 0.5922 - val_accuracy: 0.7096 - val_loss: 0.5774
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7225 - loss: 0.5514 - val_accuracy: 0.7259 - val_loss: 0.5547
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7519 - loss: 0.5251 - val_accuracy: 0.7463 - val_loss: 0.5270
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 865ms/step - accuracy: 0.7299 - loss: 0.5593 - val_accuracy: 0.7569 - val_loss: 0.5381
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.7762 - loss: 0.5131 - val_accuracy: 0.7635 - val_loss: 0.5408
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
#         val_acc=79.3%  AUC=0.839  F1=80.3%  κ=0.585  t=120s
# [    9] model=CNN_LSTM | keep=12 | Dropped: AF3, O2
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 854ms/step - accuracy: 0.5244 - loss: 0.6910 - val_accuracy: 0.5131 - val_loss: 0.6914
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step - accuracy: 0.5627 - loss: 0.6807 - val_accuracy: 0.6093 - val_loss: 0.6756
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 906ms/step - accuracy: 0.6019 - loss: 0.6646 - val_accuracy: 0.6052 - val_loss: 0.6698
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step - accuracy: 0.6305 - loss: 0.6442 - val_accuracy: 0.6395 - val_loss: 0.6387
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step - accuracy: 0.6815 - loss: 0.6037 - val_accuracy: 0.7129 - val_loss: 0.5885
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 869ms/step - accuracy: 0.7003 - loss: 0.5850 - val_accuracy: 0.6305 - val_loss: 0.6520
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7082 - loss: 0.5790 - val_accuracy: 0.7349 - val_loss: 0.5556
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.7405 - loss: 0.5530 - val_accuracy: 0.5571 - val_loss: 0.7402
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.6537 - loss: 0.6243 - val_accuracy: 0.7137 - val_loss: 0.5850
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7460 - loss: 0.5388 - val_accuracy: 0.7610 - val_loss: 0.5137
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.7678 - loss: 0.5141 - val_accuracy: 0.6256 - val_loss: 0.6801
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7029 - loss: 0.5994 - val_accuracy: 0.7243 - val_loss: 0.5736
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 860ms/step - accuracy: 0.7545 - loss: 0.5346 - val_accuracy: 0.7594 - val_loss: 0.5233
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7296 - loss: 0.5787 - val_accuracy: 0.7096 - val_loss: 0.5777
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7358 - loss: 0.5501 - val_accuracy: 0.6452 - val_loss: 0.6249
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.6658 - loss: 0.5999 - val_accuracy: 0.6974 - val_loss: 0.5975
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7476 - loss: 0.5311 - val_accuracy: 0.7227 - val_loss: 0.5571
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#         val_acc=76.1%  AUC=0.810  F1=78.1%  κ=0.521  t=143s
# [   10] model=CNN_LSTM | keep=12 | Dropped: AF3, P7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 851ms/step - accuracy: 0.5211 - loss: 0.6914 - val_accuracy: 0.5343 - val_loss: 0.6912
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.5609 - loss: 0.6835 - val_accuracy: 0.5832 - val_loss: 0.6796
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 0.5872 - loss: 0.6734 - val_accuracy: 0.5767 - val_loss: 0.6744
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step - accuracy: 0.6170 - loss: 0.6561 - val_accuracy: 0.6362 - val_loss: 0.6489
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 824ms/step - accuracy: 0.6660 - loss: 0.6206 - val_accuracy: 0.6615 - val_loss: 0.6186
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 809ms/step - accuracy: 0.7031 - loss: 0.5821 - val_accuracy: 0.7072 - val_loss: 0.5916
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 802ms/step - accuracy: 0.7309 - loss: 0.5514 - val_accuracy: 0.7357 - val_loss: 0.5448
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 785ms/step - accuracy: 0.7447 - loss: 0.5298 - val_accuracy: 0.7276 - val_loss: 0.5448
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.7505 - loss: 0.5226 - val_accuracy: 0.7251 - val_loss: 0.5720
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.7684 - loss: 0.4911 - val_accuracy: 0.7480 - val_loss: 0.5456
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step - accuracy: 0.7945 - loss: 0.4677 - val_accuracy: 0.7635 - val_loss: 0.5300
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.8082 - loss: 0.4370 - val_accuracy: 0.7985 - val_loss: 0.4512
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7786 - loss: 0.4983 - val_accuracy: 0.7365 - val_loss: 0.5261
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 796ms/step - accuracy: 0.7792 - loss: 0.4902 - val_accuracy: 0.7529 - val_loss: 0.5478
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7364 - loss: 0.5590 - val_accuracy: 0.6444 - val_loss: 0.6299
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7333 - loss: 0.5450 - val_accuracy: 0.7447 - val_loss: 0.5343
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step - accuracy: 0.8045 - loss: 0.4552 - val_accuracy: 0.8018 - val_loss: 0.4630
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 856ms/step - accuracy: 0.7980 - loss: 0.4328 - val_accuracy: 0.7798 - val_loss: 0.4736
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step - accuracy: 0.7978 - loss: 0.4689 - val_accuracy: 0.7113 - val_loss: 0.5994
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.7880 - loss: 0.4808 - val_accuracy: 0.7561 - val_loss: 0.4957
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.6870 - loss: 0.6341 - val_accuracy: 0.6370 - val_loss: 0.6578
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.6515 - loss: 0.6385 - val_accuracy: 0.6827 - val_loss: 0.6247
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7411 - loss: 0.5462 - val_accuracy: 0.7879 - val_loss: 0.4866
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.7529 - loss: 0.5427 - val_accuracy: 0.6615 - val_loss: 0.6399
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 17.
#         val_acc=80.2%  AUC=0.869  F1=79.8%  κ=0.604  t=197s
# [   11] model=CNN_LSTM | keep=12 | Dropped: AF3, P8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 936ms/step - accuracy: 0.5162 - loss: 0.6909 - val_accuracy: 0.5392 - val_loss: 0.6890
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step - accuracy: 0.5748 - loss: 0.6777 - val_accuracy: 0.5767 - val_loss: 0.6799
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 846ms/step - accuracy: 0.5978 - loss: 0.6695 - val_accuracy: 0.6240 - val_loss: 0.6658
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6525 - loss: 0.6419 - val_accuracy: 0.6533 - val_loss: 0.6393
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 825ms/step - accuracy: 0.6621 - loss: 0.6292 - val_accuracy: 0.5889 - val_loss: 0.6772
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step - accuracy: 0.6605 - loss: 0.6195 - val_accuracy: 0.6623 - val_loss: 0.6390
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.7005 - loss: 0.5859 - val_accuracy: 0.7039 - val_loss: 0.5744
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.7405 - loss: 0.5438 - val_accuracy: 0.7341 - val_loss: 0.5493
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7323 - loss: 0.5568 - val_accuracy: 0.7178 - val_loss: 0.5614
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7733 - loss: 0.4994 - val_accuracy: 0.7684 - val_loss: 0.5052
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7590 - loss: 0.5134 - val_accuracy: 0.7406 - val_loss: 0.5292
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7953 - loss: 0.4681 - val_accuracy: 0.8108 - val_loss: 0.4503
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 858ms/step - accuracy: 0.7984 - loss: 0.4464 - val_accuracy: 0.7749 - val_loss: 0.5160
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6866 - loss: 0.6478 - val_accuracy: 0.7137 - val_loss: 0.5757
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.6601 - loss: 0.6331 - val_accuracy: 0.6517 - val_loss: 0.6386
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7152 - loss: 0.5900 - val_accuracy: 0.7088 - val_loss: 0.5713
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7537 - loss: 0.5233 - val_accuracy: 0.7431 - val_loss: 0.5426
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7851 - loss: 0.4859 - val_accuracy: 0.7716 - val_loss: 0.5175
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7915 - loss: 0.4656 - val_accuracy: 0.7985 - val_loss: 0.4690
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
#         val_acc=81.1%  AUC=0.867  F1=82.0%  κ=0.621  t=158s
# [   12] model=CNN_LSTM | keep=12 | Dropped: AF3, T7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 844ms/step - accuracy: 0.5128 - loss: 0.6915 - val_accuracy: 0.5098 - val_loss: 0.6908
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 813ms/step - accuracy: 0.5597 - loss: 0.6818 - val_accuracy: 0.5922 - val_loss: 0.6787
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6070 - loss: 0.6649 - val_accuracy: 0.6077 - val_loss: 0.6629
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step - accuracy: 0.6317 - loss: 0.6458 - val_accuracy: 0.6003 - val_loss: 0.6792
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 826ms/step - accuracy: 0.6456 - loss: 0.6269 - val_accuracy: 0.6631 - val_loss: 0.6203
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 809ms/step - accuracy: 0.6870 - loss: 0.5978 - val_accuracy: 0.6941 - val_loss: 0.5810
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 800ms/step - accuracy: 0.7252 - loss: 0.5580 - val_accuracy: 0.7210 - val_loss: 0.5493
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.7423 - loss: 0.5279 - val_accuracy: 0.6909 - val_loss: 0.5946
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7517 - loss: 0.5203 - val_accuracy: 0.7577 - val_loss: 0.5190
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7851 - loss: 0.4690 - val_accuracy: 0.7382 - val_loss: 0.6016
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7345 - loss: 0.5616 - val_accuracy: 0.7039 - val_loss: 0.5747
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7474 - loss: 0.5329 - val_accuracy: 0.7194 - val_loss: 0.5702
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7827 - loss: 0.4791 - val_accuracy: 0.7341 - val_loss: 0.5512
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 801ms/step - accuracy: 0.6297 - loss: 0.6356 - val_accuracy: 0.5889 - val_loss: 0.6722
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.6484 - loss: 0.6408 - val_accuracy: 0.6542 - val_loss: 0.6338
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.6864 - loss: 0.5912 - val_accuracy: 0.6705 - val_loss: 0.5894
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
#         val_acc=75.8%  AUC=0.826  F1=76.5%  κ=0.515  t=134s
# [   13] model=CNN_LSTM | keep=12 | Dropped: AF3, T8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 850ms/step - accuracy: 0.5066 - loss: 0.6925 - val_accuracy: 0.5701 - val_loss: 0.6902
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 807ms/step - accuracy: 0.5685 - loss: 0.6827 - val_accuracy: 0.5962 - val_loss: 0.6795
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 843ms/step - accuracy: 0.6099 - loss: 0.6639 - val_accuracy: 0.6183 - val_loss: 0.6605
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step - accuracy: 0.6617 - loss: 0.6335 - val_accuracy: 0.6582 - val_loss: 0.6281
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.6637 - loss: 0.6145 - val_accuracy: 0.6215 - val_loss: 0.6573
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 806ms/step - accuracy: 0.6815 - loss: 0.5994 - val_accuracy: 0.7104 - val_loss: 0.5734
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7203 - loss: 0.5623 - val_accuracy: 0.7243 - val_loss: 0.5546
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step - accuracy: 0.7445 - loss: 0.5311 - val_accuracy: 0.6672 - val_loss: 0.5931
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7303 - loss: 0.5445 - val_accuracy: 0.7292 - val_loss: 0.5468
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7839 - loss: 0.4861 - val_accuracy: 0.7945 - val_loss: 0.4755
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7625 - loss: 0.5008 - val_accuracy: 0.7830 - val_loss: 0.4930
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7541 - loss: 0.4944 - val_accuracy: 0.7871 - val_loss: 0.4775
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.7301 - loss: 0.5454 - val_accuracy: 0.6990 - val_loss: 0.6027
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7364 - loss: 0.5459 - val_accuracy: 0.7504 - val_loss: 0.5541
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7525 - loss: 0.5256 - val_accuracy: 0.6158 - val_loss: 0.7489
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.5407 - loss: 0.7278 - val_accuracy: 0.5033 - val_loss: 0.6981
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.5327 - loss: 0.6847 - val_accuracy: 0.5620 - val_loss: 0.6787
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#         val_acc=79.4%  AUC=0.856  F1=81.8%  κ=0.588  t=141s
# [   14] model=CNN_LSTM | keep=12 | Dropped: AF4, F3
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 855ms/step - accuracy: 0.5260 - loss: 0.6904 - val_accuracy: 0.5326 - val_loss: 0.6882
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step - accuracy: 0.5866 - loss: 0.6770 - val_accuracy: 0.5522 - val_loss: 0.6843
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 837ms/step - accuracy: 0.5980 - loss: 0.6671 - val_accuracy: 0.6020 - val_loss: 0.6666
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step - accuracy: 0.6293 - loss: 0.6450 - val_accuracy: 0.6378 - val_loss: 0.6538
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step - accuracy: 0.6719 - loss: 0.6151 - val_accuracy: 0.7055 - val_loss: 0.5807
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step - accuracy: 0.7243 - loss: 0.5632 - val_accuracy: 0.6998 - val_loss: 0.5788
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 859ms/step - accuracy: 0.7674 - loss: 0.5065 - val_accuracy: 0.7113 - val_loss: 0.5668
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7258 - loss: 0.5345 - val_accuracy: 0.7757 - val_loss: 0.4968
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step - accuracy: 0.7768 - loss: 0.4850 - val_accuracy: 0.7993 - val_loss: 0.4593
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.7941 - loss: 0.4632 - val_accuracy: 0.8002 - val_loss: 0.4495
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.7970 - loss: 0.4611 - val_accuracy: 0.7088 - val_loss: 0.5430
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.7896 - loss: 0.4736 - val_accuracy: 0.7920 - val_loss: 0.4783
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 856ms/step - accuracy: 0.8049 - loss: 0.4605 - val_accuracy: 0.8100 - val_loss: 0.4534
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.8296 - loss: 0.4237 - val_accuracy: 0.8336 - val_loss: 0.4299
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 780ms/step - accuracy: 0.8504 - loss: 0.3738 - val_accuracy: 0.8279 - val_loss: 0.4158
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 853ms/step - accuracy: 0.8647 - loss: 0.3466 - val_accuracy: 0.8083 - val_loss: 0.4330
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.8647 - loss: 0.3361 - val_accuracy: 0.8254 - val_loss: 0.4101
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8710 - loss: 0.3245 - val_accuracy: 0.8377 - val_loss: 0.4192
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 774ms/step - accuracy: 0.8778 - loss: 0.3077 - val_accuracy: 0.8418 - val_loss: 0.3918
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.8939 - loss: 0.2707 - val_accuracy: 0.8377 - val_loss: 0.4193
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8863 - loss: 0.2785 - val_accuracy: 0.8719 - val_loss: 0.3394
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 761ms/step - accuracy: 0.9121 - loss: 0.2287 - val_accuracy: 0.8556 - val_loss: 0.3930
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9092 - loss: 0.2307 - val_accuracy: 0.8785 - val_loss: 0.3223
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9159 - loss: 0.2069 - val_accuracy: 0.8777 - val_loss: 0.3205
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.9198 - loss: 0.2019 - val_accuracy: 0.8866 - val_loss: 0.3455
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.8990 - loss: 0.2520 - val_accuracy: 0.8556 - val_loss: 0.4336
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.9172 - loss: 0.2095 - val_accuracy: 0.8711 - val_loss: 0.3718
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 770ms/step - accuracy: 0.9310 - loss: 0.1859 - val_accuracy: 0.8809 - val_loss: 0.3681
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step - accuracy: 0.9380 - loss: 0.1693 - val_accuracy: 0.8972 - val_loss: 0.3293
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.9249 - loss: 0.1996 - val_accuracy: 0.8483 - val_loss: 0.3725
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 850ms/step - accuracy: 0.9367 - loss: 0.1811 - val_accuracy: 0.8728 - val_loss: 0.3221
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9343 - loss: 0.1869 - val_accuracy: 0.8157 - val_loss: 0.4606
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.9221 - loss: 0.2033 - val_accuracy: 0.9038 - val_loss: 0.2996
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 769ms/step - accuracy: 0.9557 - loss: 0.1285 - val_accuracy: 0.9021 - val_loss: 0.2894
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9616 - loss: 0.1120 - val_accuracy: 0.8825 - val_loss: 0.3071
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 768ms/step - accuracy: 0.9616 - loss: 0.1050 - val_accuracy: 0.8638 - val_loss: 0.4000
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 768ms/step - accuracy: 0.9559 - loss: 0.1195 - val_accuracy: 0.8303 - val_loss: 0.5389
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.9506 - loss: 0.1349 - val_accuracy: 0.9005 - val_loss: 0.3511
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 765ms/step - accuracy: 0.9490 - loss: 0.1393 - val_accuracy: 0.8842 - val_loss: 0.3240
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step - accuracy: 0.9494 - loss: 0.1539 - val_accuracy: 0.8573 - val_loss: 0.3713
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 33.
#         val_acc=90.4%  AUC=0.955  F1=90.7%  κ=0.807  t=327s
# [   15] model=CNN_LSTM | keep=12 | Dropped: AF4, F4
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 847ms/step - accuracy: 0.5050 - loss: 0.6919 - val_accuracy: 0.5693 - val_loss: 0.6867
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 812ms/step - accuracy: 0.5523 - loss: 0.6819 - val_accuracy: 0.5571 - val_loss: 0.6810
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step - accuracy: 0.6093 - loss: 0.6606 - val_accuracy: 0.6281 - val_loss: 0.6478
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6505 - loss: 0.6301 - val_accuracy: 0.6900 - val_loss: 0.6031
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 0.7219 - loss: 0.5681 - val_accuracy: 0.6998 - val_loss: 0.5837
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 803ms/step - accuracy: 0.7902 - loss: 0.4798 - val_accuracy: 0.8189 - val_loss: 0.4497
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 862ms/step - accuracy: 0.7923 - loss: 0.4850 - val_accuracy: 0.7178 - val_loss: 0.5676
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 776ms/step - accuracy: 0.7713 - loss: 0.5045 - val_accuracy: 0.7871 - val_loss: 0.4951
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.8215 - loss: 0.4261 - val_accuracy: 0.8083 - val_loss: 0.4358
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.8292 - loss: 0.4059 - val_accuracy: 0.8312 - val_loss: 0.4116
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.8439 - loss: 0.3873 - val_accuracy: 0.8442 - val_loss: 0.3984
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.8511 - loss: 0.3753 - val_accuracy: 0.8499 - val_loss: 0.3813
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.8629 - loss: 0.3469 - val_accuracy: 0.8507 - val_loss: 0.3737
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.8745 - loss: 0.3298 - val_accuracy: 0.8475 - val_loss: 0.3760
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.8833 - loss: 0.3072 - val_accuracy: 0.8010 - val_loss: 0.4609
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.8547 - loss: 0.3652 - val_accuracy: 0.8622 - val_loss: 0.3669
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.8219 - loss: 0.4274 - val_accuracy: 0.8173 - val_loss: 0.4699
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.8317 - loss: 0.4318 - val_accuracy: 0.8238 - val_loss: 0.4517
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8627 - loss: 0.3554 - val_accuracy: 0.8475 - val_loss: 0.3579
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.8686 - loss: 0.3303 - val_accuracy: 0.8173 - val_loss: 0.4221
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.8539 - loss: 0.3568 - val_accuracy: 0.8638 - val_loss: 0.3312
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.8859 - loss: 0.2848 - val_accuracy: 0.8442 - val_loss: 0.3692
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.8857 - loss: 0.2791 - val_accuracy: 0.8581 - val_loss: 0.3156
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.8986 - loss: 0.2472 - val_accuracy: 0.8785 - val_loss: 0.2882
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.8904 - loss: 0.2676 - val_accuracy: 0.8312 - val_loss: 0.4141
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 770ms/step - accuracy: 0.8939 - loss: 0.2598 - val_accuracy: 0.8891 - val_loss: 0.2651
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.9068 - loss: 0.2343 - val_accuracy: 0.8817 - val_loss: 0.3129
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 770ms/step - accuracy: 0.9096 - loss: 0.2273 - val_accuracy: 0.8695 - val_loss: 0.2929
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 774ms/step - accuracy: 0.9072 - loss: 0.2245 - val_accuracy: 0.8646 - val_loss: 0.3001
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 767ms/step - accuracy: 0.8368 - loss: 0.3868 - val_accuracy: 0.8630 - val_loss: 0.3523
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 767ms/step - accuracy: 0.8859 - loss: 0.2944 - val_accuracy: 0.8222 - val_loss: 0.4044
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.8947 - loss: 0.2690 - val_accuracy: 0.8483 - val_loss: 0.3386
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 766ms/step - accuracy: 0.9151 - loss: 0.2191 - val_accuracy: 0.8760 - val_loss: 0.3115
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 26.
#         val_acc=88.9%  AUC=0.958  F1=89.2%  κ=0.778  t=264s
# [   16] model=CNN_LSTM | keep=12 | Dropped: AF4, F7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 853ms/step - accuracy: 0.5062 - loss: 0.6918 - val_accuracy: 0.5489 - val_loss: 0.6888
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step - accuracy: 0.5789 - loss: 0.6778 - val_accuracy: 0.6093 - val_loss: 0.6724
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 848ms/step - accuracy: 0.6207 - loss: 0.6569 - val_accuracy: 0.6599 - val_loss: 0.6402
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 850ms/step - accuracy: 0.6613 - loss: 0.6220 - val_accuracy: 0.7088 - val_loss: 0.5938
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 827ms/step - accuracy: 0.7178 - loss: 0.5693 - val_accuracy: 0.7610 - val_loss: 0.5218
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 877ms/step - accuracy: 0.7470 - loss: 0.5392 - val_accuracy: 0.7300 - val_loss: 0.5590
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7939 - loss: 0.4676 - val_accuracy: 0.8051 - val_loss: 0.4538
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.7739 - loss: 0.5015 - val_accuracy: 0.7855 - val_loss: 0.4755
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.7825 - loss: 0.4976 - val_accuracy: 0.7896 - val_loss: 0.4904
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.7786 - loss: 0.5229 - val_accuracy: 0.7471 - val_loss: 0.5358
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.5464 - loss: 0.7065 - val_accuracy: 0.5587 - val_loss: 0.6808
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.5752 - loss: 0.6753 - val_accuracy: 0.5987 - val_loss: 0.6713
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6293 - loss: 0.6475 - val_accuracy: 0.6395 - val_loss: 0.6496
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.6927 - loss: 0.5924 - val_accuracy: 0.6925 - val_loss: 0.6012
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
#         val_acc=80.5%  AUC=0.876  F1=80.9%  κ=0.610  t=118s
# [   17] model=CNN_LSTM | keep=12 | Dropped: AF4, F8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 852ms/step - accuracy: 0.5195 - loss: 0.6910 - val_accuracy: 0.5693 - val_loss: 0.6872
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 820ms/step - accuracy: 0.5987 - loss: 0.6750 - val_accuracy: 0.5799 - val_loss: 0.6746
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 913ms/step - accuracy: 0.6301 - loss: 0.6504 - val_accuracy: 0.5930 - val_loss: 0.6668
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 829ms/step - accuracy: 0.6427 - loss: 0.6390 - val_accuracy: 0.6656 - val_loss: 0.6227
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.7035 - loss: 0.5900 - val_accuracy: 0.6941 - val_loss: 0.5854
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 804ms/step - accuracy: 0.7429 - loss: 0.5312 - val_accuracy: 0.7594 - val_loss: 0.5150
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.7527 - loss: 0.5245 - val_accuracy: 0.7504 - val_loss: 0.5173
# Epoch 8/50
# ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7111 - loss: 0.5684 - val_accuracy: 0.6819 - val_loss: 0.6035
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6621 - loss: 0.7273 - val_accuracy: 0.6697 - val_loss: 0.6813
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step - accuracy: 0.6570 - loss: 0.6575 - val_accuracy: 0.6941 - val_loss: 0.6321
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 776ms/step - accuracy: 0.7107 - loss: 0.6204 - val_accuracy: 0.7162 - val_loss: 0.5903
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7592 - loss: 0.5352 - val_accuracy: 0.7488 - val_loss: 0.5297
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.7333 - loss: 0.5590 - val_accuracy: 0.7121 - val_loss: 0.5602
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.7186 - loss: 0.5510 - val_accuracy: 0.7284 - val_loss: 0.5680
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 26.
#         val_acc=81.9%  AUC=0.894  F1=83.3%  κ=0.637  t=268s
# [   86] model=CNN_LSTM | keep=12 | Dropped: P7, P8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 847ms/step - accuracy: 0.5105 - loss: 0.6930 - val_accuracy: 0.5343 - val_loss: 0.6912
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 823ms/step - accuracy: 0.5687 - loss: 0.6840 - val_accuracy: 0.5530 - val_loss: 0.6829
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 839ms/step - accuracy: 0.6093 - loss: 0.6654 - val_accuracy: 0.6395 - val_loss: 0.6563
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step - accuracy: 0.6607 - loss: 0.6321 - val_accuracy: 0.6542 - val_loss: 0.6398
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 895ms/step - accuracy: 0.7041 - loss: 0.5798 - val_accuracy: 0.7121 - val_loss: 0.5827
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 807ms/step - accuracy: 0.7515 - loss: 0.5238 - val_accuracy: 0.7610 - val_loss: 0.5133
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 802ms/step - accuracy: 0.7629 - loss: 0.5107 - val_accuracy: 0.7382 - val_loss: 0.5343
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7741 - loss: 0.4834 - val_accuracy: 0.7773 - val_loss: 0.4912
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7209 - loss: 0.6188 - val_accuracy: 0.7349 - val_loss: 0.5752
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 845ms/step - accuracy: 0.7090 - loss: 0.5972 - val_accuracy: 0.7618 - val_loss: 0.5636
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 785ms/step - accuracy: 0.7711 - loss: 0.5289 - val_accuracy: 0.8067 - val_loss: 0.4788
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7851 - loss: 0.5024 - val_accuracy: 0.7316 - val_loss: 0.5754
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7705 - loss: 0.5192 - val_accuracy: 0.7659 - val_loss: 0.5284
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.8096 - loss: 0.4597 - val_accuracy: 0.8042 - val_loss: 0.4593
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7870 - loss: 0.4966 - val_accuracy: 0.7374 - val_loss: 0.6099
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7376 - loss: 0.5658 - val_accuracy: 0.7129 - val_loss: 0.6028
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7762 - loss: 0.5202 - val_accuracy: 0.7928 - val_loss: 0.4860
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7972 - loss: 0.4784 - val_accuracy: 0.7945 - val_loss: 0.4890
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
#         val_acc=80.7%  AUC=0.851  F1=81.8%  κ=0.613  t=150s
# [   87] model=CNN_LSTM | keep=12 | Dropped: P7, T7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 867ms/step - accuracy: 0.5095 - loss: 0.6928 - val_accuracy: 0.5294 - val_loss: 0.6906
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.5723 - loss: 0.6825 - val_accuracy: 0.6134 - val_loss: 0.6739
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6219 - loss: 0.6635 - val_accuracy: 0.6305 - val_loss: 0.6500
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6464 - loss: 0.6417 - val_accuracy: 0.6746 - val_loss: 0.6243
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 824ms/step - accuracy: 0.6850 - loss: 0.6011 - val_accuracy: 0.6925 - val_loss: 0.5889
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 814ms/step - accuracy: 0.7141 - loss: 0.5596 - val_accuracy: 0.7031 - val_loss: 0.5652
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7564 - loss: 0.5104 - val_accuracy: 0.5498 - val_loss: 0.9682
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.6635 - loss: 0.6526 - val_accuracy: 0.6558 - val_loss: 0.6060
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7235 - loss: 0.5615 - val_accuracy: 0.7015 - val_loss: 0.5914
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7462 - loss: 0.5386 - val_accuracy: 0.7398 - val_loss: 0.5373
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 854ms/step - accuracy: 0.7829 - loss: 0.4876 - val_accuracy: 0.8034 - val_loss: 0.4689
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.5507 - loss: 0.7190 - val_accuracy: 0.5987 - val_loss: 0.6820
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step - accuracy: 0.5148 - loss: 0.6873 - val_accuracy: 0.5188 - val_loss: 0.6834
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.6066 - loss: 0.6690 - val_accuracy: 0.6150 - val_loss: 0.6602
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step - accuracy: 0.6713 - loss: 0.6286 - val_accuracy: 0.6525 - val_loss: 0.6374
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.6931 - loss: 0.5918 - val_accuracy: 0.6672 - val_loss: 0.6124
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step - accuracy: 0.7117 - loss: 0.5691 - val_accuracy: 0.7080 - val_loss: 0.5658
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 799ms/step - accuracy: 0.7617 - loss: 0.5047 - val_accuracy: 0.6974 - val_loss: 0.6079
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
#         val_acc=80.3%  AUC=0.855  F1=81.3%  κ=0.607  t=150s
# [   88] model=CNN_LSTM | keep=12 | Dropped: P7, T8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 854ms/step - accuracy: 0.5132 - loss: 0.6926 - val_accuracy: 0.5824 - val_loss: 0.6893
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 819ms/step - accuracy: 0.5715 - loss: 0.6818 - val_accuracy: 0.5587 - val_loss: 0.6857
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 840ms/step - accuracy: 0.6093 - loss: 0.6630 - val_accuracy: 0.5693 - val_loss: 0.6791
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step - accuracy: 0.6333 - loss: 0.6462 - val_accuracy: 0.6183 - val_loss: 0.6578
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 818ms/step - accuracy: 0.6931 - loss: 0.6015 - val_accuracy: 0.6639 - val_loss: 0.6364
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 810ms/step - accuracy: 0.7076 - loss: 0.5787 - val_accuracy: 0.7235 - val_loss: 0.5591
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 867ms/step - accuracy: 0.7215 - loss: 0.5536 - val_accuracy: 0.7398 - val_loss: 0.5365
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.7656 - loss: 0.5004 - val_accuracy: 0.7659 - val_loss: 0.5124
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7870 - loss: 0.4719 - val_accuracy: 0.8067 - val_loss: 0.4526
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.8137 - loss: 0.4478 - val_accuracy: 0.7626 - val_loss: 0.5742
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.6672 - loss: 0.6143 - val_accuracy: 0.7210 - val_loss: 0.6332
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.7568 - loss: 0.5719 - val_accuracy: 0.7830 - val_loss: 0.5022
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.6631 - loss: 0.6557 - val_accuracy: 0.6762 - val_loss: 0.6172
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 795ms/step - accuracy: 0.5848 - loss: 0.6212 - val_accuracy: 0.7145 - val_loss: 0.5850
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7609 - loss: 0.5464 - val_accuracy: 0.7268 - val_loss: 0.5725
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step - accuracy: 0.7280 - loss: 0.5758 - val_accuracy: 0.7423 - val_loss: 0.5726
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
#         val_acc=80.7%  AUC=0.872  F1=82.1%  κ=0.613  t=134s
# [   89] model=CNN_LSTM | keep=12 | Dropped: P8, T7
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 841ms/step - accuracy: 0.5105 - loss: 0.6922 - val_accuracy: 0.5604 - val_loss: 0.6885
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 802ms/step - accuracy: 0.5729 - loss: 0.6791 - val_accuracy: 0.6142 - val_loss: 0.6705
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 836ms/step - accuracy: 0.6437 - loss: 0.6397 - val_accuracy: 0.5922 - val_loss: 0.7350
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step - accuracy: 0.6325 - loss: 0.6445 - val_accuracy: 0.6680 - val_loss: 0.6232
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 835ms/step - accuracy: 0.6674 - loss: 0.6168 - val_accuracy: 0.6697 - val_loss: 0.6233
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 811ms/step - accuracy: 0.7046 - loss: 0.5848 - val_accuracy: 0.7072 - val_loss: 0.5790
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 805ms/step - accuracy: 0.7398 - loss: 0.5423 - val_accuracy: 0.7251 - val_loss: 0.5516
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7617 - loss: 0.5168 - val_accuracy: 0.7488 - val_loss: 0.5330
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7919 - loss: 0.4776 - val_accuracy: 0.7896 - val_loss: 0.4811
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 854ms/step - accuracy: 0.7964 - loss: 0.4691 - val_accuracy: 0.8042 - val_loss: 0.4657
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7856 - loss: 0.4758 - val_accuracy: 0.7749 - val_loss: 0.4755
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 789ms/step - accuracy: 0.7747 - loss: 0.4822 - val_accuracy: 0.5155 - val_loss: 0.6689
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 786ms/step - accuracy: 0.6435 - loss: 0.6342 - val_accuracy: 0.7121 - val_loss: 0.5970
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7258 - loss: 0.5607 - val_accuracy: 0.7382 - val_loss: 0.5402
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 806ms/step - accuracy: 0.7923 - loss: 0.4746 - val_accuracy: 0.8083 - val_loss: 0.4631
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 801ms/step - accuracy: 0.7849 - loss: 0.5072 - val_accuracy: 0.7708 - val_loss: 0.5087
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 800ms/step - accuracy: 0.8111 - loss: 0.4574 - val_accuracy: 0.7904 - val_loss: 0.4806
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 791ms/step - accuracy: 0.7192 - loss: 0.6232 - val_accuracy: 0.6542 - val_loss: 0.7726
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.5838 - loss: 0.6596 - val_accuracy: 0.6297 - val_loss: 0.6675
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7011 - loss: 0.6559 - val_accuracy: 0.7520 - val_loss: 0.6231
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 792ms/step - accuracy: 0.7698 - loss: 0.5890 - val_accuracy: 0.7741 - val_loss: 0.5560
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step - accuracy: 0.6068 - loss: 0.6954 - val_accuracy: 0.5147 - val_loss: 0.7750
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 15.
#         val_acc=80.8%  AUC=0.867  F1=80.3%  κ=0.617  t=183s
# [   90] model=CNN_LSTM | keep=12 | Dropped: P8, T8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 862ms/step - accuracy: 0.5091 - loss: 0.6924 - val_accuracy: 0.5905 - val_loss: 0.6882
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 888ms/step - accuracy: 0.5929 - loss: 0.6764 - val_accuracy: 0.6313 - val_loss: 0.6648
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 849ms/step - accuracy: 0.6590 - loss: 0.6369 - val_accuracy: 0.6436 - val_loss: 0.6392
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 865ms/step - accuracy: 0.6921 - loss: 0.5915 - val_accuracy: 0.6444 - val_loss: 0.6417
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 828ms/step - accuracy: 0.6980 - loss: 0.5873 - val_accuracy: 0.7088 - val_loss: 0.5710
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 815ms/step - accuracy: 0.7607 - loss: 0.5195 - val_accuracy: 0.7569 - val_loss: 0.5343
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 801ms/step - accuracy: 0.7686 - loss: 0.5172 - val_accuracy: 0.7537 - val_loss: 0.5174
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.7584 - loss: 0.5193 - val_accuracy: 0.7170 - val_loss: 0.5776
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7260 - loss: 0.5675 - val_accuracy: 0.7268 - val_loss: 0.5657
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 0.7439 - loss: 0.5471 - val_accuracy: 0.7863 - val_loss: 0.4963
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7352 - loss: 0.5576 - val_accuracy: 0.7251 - val_loss: 0.5879
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 857ms/step - accuracy: 0.7231 - loss: 0.5736 - val_accuracy: 0.7170 - val_loss: 0.5728
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.7509 - loss: 0.5335 - val_accuracy: 0.7471 - val_loss: 0.5311
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.7805 - loss: 0.4904 - val_accuracy: 0.7716 - val_loss: 0.5151
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 793ms/step - accuracy: 0.7796 - loss: 0.4889 - val_accuracy: 0.7790 - val_loss: 0.4763
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 798ms/step - accuracy: 0.7984 - loss: 0.4620 - val_accuracy: 0.7365 - val_loss: 0.5303
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 860ms/step - accuracy: 0.7819 - loss: 0.4806 - val_accuracy: 0.7643 - val_loss: 0.5078
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#         val_acc=78.6%  AUC=0.847  F1=80.2%  κ=0.572  t=143s
# [   91] model=CNN_LSTM | keep=12 | Dropped: T7, T8
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 12s 850ms/step - accuracy: 0.5072 - loss: 0.6922 - val_accuracy: 0.5416 - val_loss: 0.6882
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 817ms/step - accuracy: 0.5789 - loss: 0.6775 - val_accuracy: 0.6150 - val_loss: 0.6709
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 838ms/step - accuracy: 0.6150 - loss: 0.6584 - val_accuracy: 0.5636 - val_loss: 0.6944
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 847ms/step - accuracy: 0.6299 - loss: 0.6433 - val_accuracy: 0.6272 - val_loss: 0.6568
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 818ms/step - accuracy: 0.6850 - loss: 0.6051 - val_accuracy: 0.7064 - val_loss: 0.5847
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 808ms/step - accuracy: 0.7445 - loss: 0.5433 - val_accuracy: 0.7398 - val_loss: 0.5554
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 872ms/step - accuracy: 0.7427 - loss: 0.5409 - val_accuracy: 0.6876 - val_loss: 0.6056
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.7562 - loss: 0.5274 - val_accuracy: 0.7667 - val_loss: 0.5163
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 790ms/step - accuracy: 0.8002 - loss: 0.4614 - val_accuracy: 0.7822 - val_loss: 0.5020
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 858ms/step - accuracy: 0.7686 - loss: 0.5003 - val_accuracy: 0.6958 - val_loss: 0.5589
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 783ms/step - accuracy: 0.7176 - loss: 0.5532 - val_accuracy: 0.7080 - val_loss: 0.5482
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.6660 - loss: 0.6168 - val_accuracy: 0.7325 - val_loss: 0.5837
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 782ms/step - accuracy: 0.7525 - loss: 0.5268 - val_accuracy: 0.7496 - val_loss: 0.5318
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 784ms/step - accuracy: 0.6280 - loss: 0.5910 - val_accuracy: 0.5098 - val_loss: 0.6368
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.7174 - loss: 0.5828 - val_accuracy: 0.7431 - val_loss: 0.5491
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 778ms/step - accuracy: 0.7311 - loss: 0.5917 - val_accuracy: 0.7104 - val_loss: 0.5896
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 9.
#         val_acc=78.2%  AUC=0.839  F1=79.2%  κ=0.564  t=136s
#
# Done. Combinations run: 91

# %% [markdown]
# ## Cell 6 – Save All Metrics to Excel

# %%
results_df   = pd.DataFrame(all_results)
summary_path = os.path.join(OUT_ROOT, f'{MODEL_NAME}_AllCombos_Summary.xlsx')

with pd.ExcelWriter(summary_path, engine='openpyxl') as writer:
    results_df.to_excel(writer, sheet_name='All Results', index=False)
    results_df.sort_values('val_acc', ascending=False).to_excel(
        writer, sheet_name='Sorted by Accuracy', index=False)
    results_df.sort_values('auc', ascending=False).to_excel(
        writer, sheet_name='Sorted by AUC', index=False)
    results_df.sort_values('f1', ascending=False).to_excel(
        writer, sheet_name='Sorted by F1', index=False)
    results_df.sort_values('cohen_kappa', ascending=False).to_excel(
        writer, sheet_name='Sorted by Kappa', index=False)

print(f'Summary saved → {summary_path}')
results_df.head()
# Out:
# Summary saved → outputs_CNN_LSTM/CNN_LSTM_AllCombos_Summary.xlsx
#       model              title                fname  n_keep  \
# 0  CNN_LSTM  Dropped: AF3, AF4  keep12_drop_AF3_AF4      12
# 1  CNN_LSTM   Dropped: AF3, F3   keep12_drop_AF3_F3      12
# 2  CNN_LSTM   Dropped: AF3, F4   keep12_drop_AF3_F4      12
# 3  CNN_LSTM   Dropped: AF3, F7   keep12_drop_AF3_F7      12
# 4  CNN_LSTM   Dropped: AF3, F8   keep12_drop_AF3_F8      12
#
#                                                 kept   dropped    val_acc  \
# 0   F3, F4, F7, F8, FC5, FC6, O1, O2, P7, P8, T7, T8  AF3, AF4  80.424142
# 1  AF4, F4, F7, F8, FC5, FC6, O1, O2, P7, P8, T7, T8   AF3, F3  75.856441
# 2  AF4, F3, F7, F8, FC5, FC6, O1, O2, P7, P8, T7, T8   AF3, F4  79.037523
# 3  AF4, F3, F4, F8, FC5, FC6, O1, O2, P7, P8, T7, T8   AF3, F7  73.817295
# 4  AF4, F3, F4, F7, FC5, FC6, O1, O2, P7, P8, T7, T8   AF3, F8  77.487767
#
#    val_loss       auc  precision     recall         f1  cohen_kappa   tn   fp  \
# 0  0.471945  0.852536  75.438596  90.599676  82.326951     0.607949  427  182
# 1  0.525806  0.815852  76.884422  74.392220  75.617792     0.517211  471  138
# 2  0.497118  0.843551  80.201342  77.471637  78.812861     0.580826  491  118
# 3  0.526169  0.819858  68.181818  89.951378  77.568134     0.475223  350  259
# 4  0.513473  0.832286  71.664549  91.410049  80.341880     0.548920  386  223
#
#     fn   tp  train_time_s
# 0   58  559         228.6
# 1  158  459         165.2
# 2  139  478         141.4
# 3   62  555         120.1
# 4   53  564         173.5

# %% [markdown]
# ## Cell 7 – Summary Plots

# %%
fw, fs = 'bold', 12

# ── 7a. Box-plots: metric distribution per subset size ───────────────────────
for metric, ylabel, plot_title in [
    ('val_acc', 'Validation Accuracy (%)', 'Accuracy by Subset Size'),
    ('auc',     'AUC',                     'AUC by Subset Size'),
    ('f1',      'F1 Score (%)',            'F1 Score by Subset Size'),
]:
    grouped = [results_df.loc[results_df['n_keep'] == k, metric].values
               for k in range(1, 15)]
    fig, ax = plt.subplots(figsize=(10, 5))
    bp = ax.boxplot(grouped, patch_artist=True,
                    boxprops=dict(facecolor='#00ABCD', color='#121212'),
                    medianprops=dict(color='#FF4500', linewidth=2))
    ax.set_title(f'{MODEL_NAME} – {plot_title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Number of Channels Kept', fontweight=fw, fontsize=fs)
    ax.set_ylabel(ylabel, fontweight=fw, fontsize=fs)
    ax.set_xticks(range(1, 15)); ax.set_xticklabels(range(1, 15), fontweight=fw)
    ax.tick_params(labelsize=fs)
    plt.tight_layout()
    out_path = os.path.join(OUT_ROOT, f'summary_boxplot_{metric}.png')
    fig.savefig(out_path, dpi=150); plt.close(fig)
    print(f'Saved: {out_path}')


# ── 7b. Top-10 by accuracy ───────────────────────────────────────────────────
top10 = results_df.sort_values('val_acc', ascending=False).head(10)
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title(f'{MODEL_NAME} – Top-10 Combinations by Validation Accuracy',
             fontweight=fw, fontsize=fs)
ax.set_xlabel('Validation Accuracy (%)', fontweight=fw, fontsize=fs)
hbars = ax.barh(range(len(top10)), top10['val_acc'].values, color='#121212')
ax.bar_label(hbars, fmt=lambda x: f'{x:.1f}%', fontsize=fs, fontweight=fw)
ax.set_yticks(range(len(top10)))
ax.set_yticklabels(top10['title'].values, fontweight=fw, fontsize=10)
ax.set_xlim(0, 110)
plt.tight_layout()
out_path = os.path.join(OUT_ROOT, 'summary_top10_accuracy.png')
fig.savefig(out_path, dpi=150); plt.close(fig)
print(f'Saved: {out_path}')


# ── 7c. Channel importance (Δ accuracy) ─────────────────────────────────────
mean_acc_with    = {}
mean_acc_without = {}
for ch in CHANNEL_NAMES:
    mean_acc_with[ch]    = results_df[results_df['kept'].str.contains(ch)]['val_acc'].mean()
    mean_acc_without[ch] = results_df[~results_df['kept'].str.contains(ch)]['val_acc'].mean()

importance_df = pd.DataFrame({
    'Channel':          CHANNEL_NAMES,
    'Mean Acc With':    [mean_acc_with[c]    for c in CHANNEL_NAMES],
    'Mean Acc Without': [mean_acc_without[c] for c in CHANNEL_NAMES],
})
importance_df['Delta'] = importance_df['Mean Acc With'] - importance_df['Mean Acc Without']
importance_df = importance_df.sort_values('Delta', ascending=True)

fig, ax = plt.subplots(figsize=(8, 6))
colors = ['#121212' if d >= 0 else '#CC0000' for d in importance_df['Delta']]
hbars = ax.barh(range(len(importance_df)), importance_df['Delta'].values, color=colors)
ax.bar_label(hbars, fmt=lambda x: f'{x:+.2f}%', fontsize=fs, fontweight=fw)
ax.set_title(f'{MODEL_NAME} – Channel Importance\n(Mean Acc with − without)',
             fontweight=fw, fontsize=fs)
ax.set_xlabel('Δ Accuracy (%)', fontweight=fw, fontsize=fs)
ax.set_yticks(range(len(importance_df)))
ax.set_yticklabels(importance_df['Channel'].values, fontweight=fw, fontsize=fs)
ax.axvline(0, color='grey', linewidth=0.8, linestyle='--')
plt.tight_layout()
out_path = os.path.join(OUT_ROOT, 'summary_channel_importance.png')
fig.savefig(out_path, dpi=150); plt.close(fig)
print(f'Saved: {out_path}')

importance_df.to_csv(os.path.join(OUT_ROOT, 'channel_importance.csv'), index=False)
print('All summary plots saved.')
importance_df.sort_values('Delta', ascending=False)
# Out:
# Saved: outputs_CNN_LSTM/summary_boxplot_val_acc.png
# Saved: outputs_CNN_LSTM/summary_boxplot_auc.png
# Saved: outputs_CNN_LSTM/summary_boxplot_f1.png
# Saved: outputs_CNN_LSTM/summary_top10_accuracy.png
# Saved: outputs_CNN_LSTM/summary_channel_importance.png
# All summary plots saved.
#    Channel  Mean Acc With  Mean Acc Without     Delta
# 2       F3      80.976980         75.856441  5.120539
# 0      AF3      81.340193         78.403815  2.936378
# 8       O1      81.235621         79.031246  2.204375
# 9       O2      81.205295         79.213202  1.992093
# 12      T7      81.199021         79.250847  1.948174
# 4       F7      81.159284         79.489271  1.670013
# 10      P7      80.995106         80.474339  0.520767
# 7      FC6      80.988832         80.511984  0.476847
# 5       F8      80.814197         81.559794 -0.745598
# 13      T8      80.744134         81.980172 -1.236039
# 11      P8      80.734722         82.036642 -1.301920
# 1      AF4      80.470155         83.624042 -3.153887
# 6      FC5      80.425189         83.893838 -3.468649
# 3       F4      80.831974         88.907015 -8.075041

# %%
from google.colab import drive
import shutil
from google.colab import files

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Your folder path
folder_path = "/content/drive/MyDrive/thesis_works/outputs_CNN_LSTM"

# Step 3: Name of output zip file (will be created in /content)
output_filename = "outputs_CNN_LSTM_N_summary"

# Step 4: Create zip file
shutil.make_archive(output_filename, 'zip', folder_path)

# Step 5: Download zip to your computer
files.download(output_filename + ".zip")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
