# %% [markdown]
# # EEG Epilepsy – All Channel Combinations × 4 Models
#
# Trains one of four model architectures for every possible subset of the 14 EEG channels.
#
# **Models available** (set `MODEL_NAME` in Cell 1):
# | Key | Architecture |
# |---|---|
# | `'CNN'` | 1-D CNN (5 Conv blocks → GAP → Dense) |
# | `'ChronoNet'` | 3 inception-style Conv blocks → 4 skip-connected GRUs |
# | `'CNN_LSTM'` | Deep CNN (Conv→Pool stack) → 2 LSTMs → Dense head |
# | `'IC_RNN'` | Inception Conv blocks → 4 plain GRUs (no skip connections) |
#
# **Structure**
# 1. Imports & Global Settings
# 2. Load Pre-extracted Features
# 3. Model Builders
# 4. Helper Functions
# 5. Main Training Loop
# 6. Save Metrics to Excel
# 7. Summary Plots

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/thesis_works
# Out:
# /content/drive/MyDrive/thesis_works

# %%
from google.colab import drive
import shutil
from google.colab import files

# %% [markdown]
# ## Cell 1 – Imports & Global Settings

# %%
# ── Standard library ────────────────────────────────────────────────────────
import os
import itertools
import random
import time
from itertools import combinations

# ── Numerical / data ────────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ── Plotting ────────────────────────────────────────────────────────────────
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt

# ── Scikit-learn ────────────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, cohen_kappa_score

# ── TensorFlow / Keras ──────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv1D, BatchNormalization, LeakyReLU,
    MaxPool1D, AveragePooling1D, GlobalAveragePooling1D,
    Dense, Dropout, LSTM, GRU, concatenate, Input,
)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import EarlyStopping
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  >>>  CHOOSE YOUR MODEL HERE  <<<                                       ║
# ║  Options: 'CNN'  |  'ChronoNet'  |  'CNN_LSTM'  |  'IC_RNN'            ║
# ╚══════════════════════════════════════════════════════════════════════════╝
MODEL_NAME = 'CNN_LSTM'      # <── change this

# ── Hyper-parameters ────────────────────────────────────────────────────────
EPOCHS      = 100
BATCH_SIZE  = 512
LR          = 0.0006
TEST_SIZE   = 0.2
RANDOM_SEED = 42

# ── Channel meta-data ───────────────────────────────────────────────────────
ALL_CHANNELS  = list(range(1, 15))   # 1-based indices
CHANNEL_NAMES = [
    'AF3','AF4','F3','F4','F7','F8',
    'FC5','FC6','O1','O2','P7','P8','T7','T8'
]

# ── Output root folder ──────────────────────────────────────────────────────
OUT_ROOT = f'outputs_{MODEL_NAME}'
os.makedirs(OUT_ROOT, exist_ok=True)

assert MODEL_NAME in ('CNN', 'ChronoNet', 'CNN_LSTM', 'IC_RNN'), \
    f"Unknown MODEL_NAME '{MODEL_NAME}'. Choose from: CNN, ChronoNet, CNN_LSTM, IC_RNN"

print('Setup complete.')
print(f'TensorFlow version : {tf.__version__}')
print(f'Selected model     : {MODEL_NAME}')
print(f'Output root        : {OUT_ROOT}/')
# Out:
# Setup complete.
# TensorFlow version : 2.20.0
# Selected model     : CNN
# Output root        : outputs_CNN/

# %% [markdown]
# ## Cell 2 – Load Pre-extracted Features

# %%
FEATURE_DIR    = 'nigeria_features'
FEATURE_PREFIX = 'features_Nigeria_channel_'
LABELS_FILE    = f'{FEATURE_DIR}/labels_groups_Nigeria.xlsx'

for its, j in enumerate(range(1, 15)):
    csv_path = f'{FEATURE_DIR}/{FEATURE_PREFIX}{j-1}.csv'
    df1 = pd.read_csv(csv_path, header=0, index_col=0).values   # (N, 640)
    if its == 0:
        df1a = df1[..., np.newaxis]
    else:
        df1a = np.concatenate((df1a, df1[..., np.newaxis]), axis=2)

print(f'Feature array shape : {df1a.shape}')   # (N, 640, 14)

df2 = pd.read_excel(LABELS_FILE, sheet_name='label_array',  header=0, index_col=0)
df3 = pd.read_excel(LABELS_FILE, sheet_name='group_array',  header=0, index_col=0)

print(f'Labels shape        : {df2.shape}')
print(f'Class balance:\n{df2.iloc[:,0].value_counts()}')
# Out:
# Feature array shape : (6127, 640, 14)
# Labels shape        : (6127, 1)
# Class balance:
# 0
# 1    3085
# 0    3042
# Name: count, dtype: int64

# %% [markdown]
# ## Cell 3 – Model Builders
#
# Each function accepts `n_channels` (number of EEG channels in the current
# subset) and `lr`, and returns a **compiled** Keras model.

# %%
# ────────────────────────────────────────────────────────────────────────────
# 1.  CNN  (original notebook architecture)
# ────────────────────────────────────────────────────────────────────────────

def build_CNN(n_channels: int, lr: float = LR) -> Sequential:
    clear_session()

    model = Sequential([
        tf.keras.Input(shape=(640, n_channels)),
        Conv1D(5, 3, strides=1, name='Conv1D_1'),
        BatchNormalization(name='BN_1'),
        LeakyReLU(name='LReLU_1'),
        MaxPool1D(2, 2, name='MaxPool_1'),

        Conv1D(5, 3, strides=1, name='Conv1D_2'),
        LeakyReLU(name='LReLU_2'),
        MaxPool1D(2, 2, name='MaxPool_2'),
        Dropout(0.2, name='Dropout_1'),

        Conv1D(5, 3, strides=1, name='Conv1D_3'),
        LeakyReLU(name='LReLU_3'),
        AveragePooling1D(2, 2, name='AvgPool_1'),
        Dropout(0.2, name='Dropout_2'),

        Conv1D(5, 3, strides=1, name='Conv1D_4'),
        LeakyReLU(name='LReLU_4'),
        AveragePooling1D(2, 2, name='AvgPool_2'),

        Conv1D(5, 3, strides=1, name='Conv1D_5'),
        LeakyReLU(name='LReLU_5'),

        GlobalAveragePooling1D(name='GAP'),
        Dense(1, activation='sigmoid', name='Output'),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )

    return model

# ────────────────────────────────────────────────────────────────────────────
# 2.  ChronoNet  (inception-style Conv blocks + skip-connected GRUs)
# ────────────────────────────────────────────────────────────────────────────
def build_ChronoNet(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    def _block(x, layer_no):
        c1 = Conv1D(32, 2, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_A_{layer_no}')(x)
        c2 = Conv1D(32, 4, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_B_{layer_no}')(x)
        c3 = Conv1D(32, 8, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_C_{layer_no}')(x)
        return concatenate([c1, c2, c3], axis=2, name=f'Concat_{layer_no}')

    inp    = Input(shape=(640, n_channels), name='InputLayer')
    b1     = _block(inp, 1)
    b2     = _block(b1,  2)
    b3     = _block(b2,  3)

    g1     = GRU(32, activation='tanh', return_sequences=True, name='GRU_1')(b3)
    g2     = GRU(32, activation='tanh', return_sequences=True, name='GRU_2')(g1)
    g2a    = concatenate([g1, g2], axis=2, name='Concat_4')
    g3     = GRU(32, activation='tanh', return_sequences=True, name='GRU_3')(g2a)
    g3a    = concatenate([g1, g2, g3], name='Concat_5')
    g4     = GRU(32, activation='tanh', name='GRU_4')(g3a)
    out    = Dense(1, activation='sigmoid', name='Output')(g4)

    model  = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ────────────────────────────────────────────────────────────────────────────
# 3.  CNN-LSTM  (deep CNN stack + 2 LSTM layers)
# ────────────────────────────────────────────────────────────────────────────
def build_CNN_LSTM(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    inp  = Input(shape=(640, n_channels), name='InputLayer')
    x    = Conv1D(64,   3, strides=1, activation='relu', padding='causal', name='Conv1D_1')(inp)
    x    = MaxPool1D(2, 2, name='MaxPool_1')(x)
    x    = Conv1D(128,  3, strides=1, activation='relu', padding='causal', name='Conv1D_2')(x)
    x    = Conv1D(512,  3, strides=1, activation='relu', padding='causal', name='Conv1D_3')(x)
    x    = Conv1D(1024, 3, strides=1, activation='relu', padding='causal', name='Conv1D_4')(x)
    x    = Dense(256, activation='relu', name='Dense_1')(x)
    x    = Dropout(0.5, name='Dropout_1')(x)
    x, *_= LSTM(64, return_sequences=True, return_state=True, name='LSTM_1')(x)
    x    = LSTM(64, name='LSTM_2')(x)
    x    = Dense(256, activation='relu', name='Dense_2')(x)
    x    = Dense(128, activation='relu', name='Dense_3')(x)
    x    = Dense(64,  activation='relu', name='Dense_4')(x)
    out  = Dense(1, activation='sigmoid', name='Output')(x)

    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ────────────────────────────────────────────────────────────────────────────
# 4.  IC-RNN  (inception Conv blocks + 4 plain GRUs, no skip connections)
# ────────────────────────────────────────────────────────────────────────────
def build_IC_RNN(n_channels: int, lr: float = LR) -> Model:
    clear_session()

    def _block(x, layer_no):
        c1 = Conv1D(32, 2, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_A_{layer_no}')(x)
        c2 = Conv1D(32, 4, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_B_{layer_no}')(x)
        c3 = Conv1D(32, 8, strides=2, activation='relu', padding='causal',
                    name=f'Conv1D_C_{layer_no}')(x)
        return concatenate([c1, c2, c3], axis=2, name=f'Concat_{layer_no}')

    inp = Input(shape=(640, n_channels), name='InputLayer')
    b1  = _block(inp, 1)
    b2  = _block(b1,  2)
    b3  = _block(b2,  3)

    g1  = GRU(32, activation='tanh', return_sequences=True, name='GRU_1')(b3)
    g2  = GRU(32, activation='tanh', return_sequences=True, name='GRU_2')(g1)
    g3  = GRU(32, activation='tanh', return_sequences=True, name='GRU_3')(g2)
    g4  = GRU(32, activation='tanh', name='GRU_4')(g3)
    out = Dense(1, activation='sigmoid', name='Output')(g4)

    model = Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy'],
    )
    return model


# ── Dispatch table ───────────────────────────────────────────────────────────
_BUILDERS = {
    'CNN':       build_CNN,
    'ChronoNet': build_ChronoNet,
    'CNN_LSTM':  build_CNN_LSTM,
    'IC_RNN':    build_IC_RNN,
}

def build_model(n_channels: int, lr: float = LR) -> Model:
    """Build and return the model selected by MODEL_NAME."""
    return _BUILDERS[MODEL_NAME](n_channels, lr)


print('Model builders defined.')
print(f'Active builder     : build_{MODEL_NAME}()')
# Out:
# Model builders defined.
# Active builder     : build_CNN()

# %% [markdown]
# ## Cell 4 – Helper Functions

# %%
# ────────────────────────────────────────────────────────────────────────────
# Reproducibility
# ────────────────────────────────────────────────────────────────────────────
def reset_seeds(seed: int = 42) -> None:
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()


# ────────────────────────────────────────────────────────────────────────────
# Label helpers
# ────────────────────────────────────────────────────────────────────────────
def make_combo_label(kept_indices: list, n_total: int = 14) -> dict:
    kept_names    = [CHANNEL_NAMES[i-1] for i in kept_indices]
    dropped_idx   = [j for j in ALL_CHANNELS if j not in kept_indices]
    dropped_names = [CHANNEL_NAMES[j-1] for j in dropped_idx]
    n_keep = len(kept_indices)
    n_drop = len(dropped_idx)

    if n_drop == 0:
        title = 'All 14 channels'
    elif n_keep >= 8:
        title = f'Dropped: {", ".join(dropped_names)}'
    else:
        title = f'Kept: {", ".join(kept_names)}'

    drop_str = '_'.join(dropped_names) if dropped_names else 'none'
    fname    = f'keep{n_keep:02d}_drop_{drop_str}'

    return {
        'title': title, 'fname': fname,
        'n_keep': n_keep, 'n_drop': n_drop,
        'kept_names': kept_names, 'dropped_names': dropped_names,
    }


# ────────────────────────────────────────────────────────────────────────────
# Per-combination figure saver
# ────────────────────────────────────────────────────────────────────────────
def save_figures_for_combo(history, y_test, y_pred,
                            label_info: dict, out_dir: str) -> dict:
    os.makedirs(out_dir, exist_ok=True)
    title  = label_info['title']
    fname  = label_info['fname']
    fw, fs = 'bold', 12

    y_pred_bin  = np.round(y_pred).astype(int).squeeze()
    cm          = confusion_matrix(y_test, y_pred_bin)
    cm_norm     = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    auc         = roc_auc_score(y_test, y_pred)
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    cks         = cohen_kappa_score(y_test, y_pred_bin)

    tn, fp, fn, tp = cm.ravel()
    precision = 100 * tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = 100 * tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1        = 2 * precision * recall / (precision + recall) \
                if (precision + recall) > 0 else 0.0

    #getting the best val_acc due to callback
    best_epoch = np.argmax(history.history['val_accuracy'])

    val_acc  = history.history['val_accuracy'][best_epoch] * 100
    val_loss = history.history['val_loss'][best_epoch]



    # 1. Accuracy curve
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(history.history['accuracy'],     color='#00ABCD', label='Train')
    ax.plot(history.history['val_accuracy'], color='#121212', label='Test')
    ax.set_title(f'Accuracy – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Epoch', fontweight=fw, fontsize=fs)
    ax.set_ylabel('Accuracy', fontweight=fw, fontsize=fs)
    ax.set_xlim(0, EPOCHS); ax.set_ylim(0, 1)
    ax.set_xticks(np.arange(0, EPOCHS + 1, 20))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_accuracy_curve.png'), dpi=150)
    plt.close(fig)

    # 2. Loss curve
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.plot(history.history['loss'],     color='#00ABCD', label='Train')
    ax.plot(history.history['val_loss'], color='#121212', label='Test')
    ax.set_title(f'Loss – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Epoch', fontweight=fw, fontsize=fs)
    ax.set_ylabel('Binary Cross-entropy', fontweight=fw, fontsize=fs)
    ax.set_xlim(0, EPOCHS); ax.set_ylim(0, 1)
    ax.set_xticks(np.arange(0, EPOCHS + 1, 20))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_loss_curve.png'), dpi=150)
    plt.close(fig)

    # 3. Confusion Matrix
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.matshow(cm, cmap=plt.cm.binary)
    threshold = (cm.max() + cm.min()) / 2.0
    for i_cm, j_cm in itertools.product(range(2), range(2)):
        ax.text(j_cm, i_cm, f'{cm_norm[i_cm, j_cm]*100:.1f}%',
                ha='center', va='center',
                color='white' if cm[i_cm, j_cm] > threshold else 'black',
                fontweight=fw, fontsize=fs)
    ax.set_title(f'Confusion Matrix\n{title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Predicted Label', fontweight=fw, fontsize=fs)
    ax.set_ylabel('True Label', fontweight=fw, fontsize=fs)
    ax.set_xticks([0, 1]); ax.set_yticks([0, 1])
    ax.xaxis.set_label_position('bottom'); ax.xaxis.tick_bottom()
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_confusion_matrix.png'), dpi=150)
    plt.close(fig)

    # 4. ROC curve
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.plot(fpr, tpr, color='#000000', label=f'AUC = {auc:.3f}')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=0.8)
    ax.set_title(f'ROC – {title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('False Positive Rate', fontweight=fw, fontsize=fs)
    ax.set_ylabel('True Positive Rate', fontweight=fw, fontsize=fs)
    ax.set_xticks(np.linspace(0, 1, 3)); ax.set_yticks(np.linspace(0, 1, 3))
    ax.legend(prop={'weight': fw}); ax.tick_params(labelsize=fs)
    plt.tight_layout()
    fig.savefig(os.path.join(out_dir, f'{fname}_roc_curve.png'), dpi=150)
    plt.close(fig)

    return {
        'model':     MODEL_NAME,
        'title':     title,
        'fname':     fname,
        'n_keep':    label_info['n_keep'],
        'kept':      ', '.join(label_info['kept_names']),
        'dropped':   ', '.join(label_info['dropped_names']) or 'none',
        'val_acc':   val_acc,
        'val_loss':  val_loss,
        'auc':       auc,
        'precision': precision,
        'recall':    recall,
        'f1':        f1,
        'cohen_kappa': cks,
        'tn': tn, 'fp': fp, 'fn': fn, 'tp': tp,
    }


print('Helper functions defined.')
# Out:
# Helper functions defined.

# %% [markdown]
# ## Cell 5 – Main Training Loop
#
# Iterates over every non-empty subset of the 14 channels (2^14 − 1 = 16 383).
#
# > Set `MAX_COMBOS = None` to run all combinations.

# %%
MAX_COMBOS = None     # set to None for a full run

all_results   = []
combo_counter = 0

for n_exclude in range(2,3):                  #(0,14)
    n_keep = 14 - n_exclude

    for excl in combinations(ALL_CHANNELS, n_exclude):

        if MAX_COMBOS is not None and combo_counter >= MAX_COMBOS:
            print(f'Reached MAX_COMBOS = {MAX_COMBOS}. Stopping.')
            break

        my_list    = [j for j in ALL_CHANNELS if j not in excl]
        label_info = make_combo_label(my_list)
        combo_counter += 1

        print(f'[{combo_counter:5d}] model={MODEL_NAME} | keep={n_keep:2d} | {label_info["title"]}',
              flush=True)

        combo_dir = os.path.join(OUT_ROOT, f'keep{n_keep:02d}', label_info['fname'])
        os.makedirs(combo_dir, exist_ok=True)

        # ── Prepare data ────────────────────────────────────────────────────
        data_array  = df1a[..., np.array(my_list) - 1]   # (N, 640, n_keep)
        label_array = df2.iloc[:, 0].values

        X_train, X_test, y_train, y_test = train_test_split(
            data_array, label_array,
            test_size=TEST_SIZE, random_state=RANDOM_SEED, stratify=label_array,
        )

        sc      = StandardScaler()
        X_train = sc.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
        X_test  = sc.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

        # ── Build & train ────────────────────────────────────────────────────
        reset_seeds(RANDOM_SEED)
        model = build_model(n_channels=n_keep, lr=LR)

        t0      = time.time()

         # moving it near fit(), the goal was to ensure a fresh callback is created for every iteration:
        early_stop = tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=10,
            restore_best_weights=True,
            verbose=1,
            mode='max'
        )
        history = model.fit(
            tf.constant(X_train), tf.constant(y_train),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            validation_data=(tf.constant(X_test), y_test),
            callbacks=[early_stop],
            verbose=1
        )
        train_time = time.time() - t0

        # ── Evaluate ─────────────────────────────────────────────────────────
        y_pred = model.predict(X_test, verbose=0)

        # ── Save figures & collect metrics ────────────────────────────────────
        metrics = save_figures_for_combo(
            history=history,
            y_test=y_test,
            y_pred=y_pred,
            label_info=label_info,
            out_dir=combo_dir,
        )
        metrics['train_time_s'] = round(train_time, 1)

        # ── Save training history CSV ─────────────────────────────────────────
        pd.DataFrame(history.history).to_csv(
            os.path.join(combo_dir, f'{label_info["fname"]}_history.csv'),
            index_label='epoch',
        )

        all_results.append(metrics)
        print(f'        val_acc={metrics["val_acc"]:.1f}%  '
              f'AUC={metrics["auc"]:.3f}  '
              f'F1={metrics["f1"]:.1f}%  '
              f'κ={metrics["cohen_kappa"]:.3f}  '
              f't={train_time:.0f}s',
              flush=True)

    else:
        continue
    break

print(f'\nDone. Combinations run: {combo_counter}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5587 - loss: 0.6837 - val_accuracy: 0.5759 - val_loss: 0.6826
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5609 - loss: 0.6838 - val_accuracy: 0.5799 - val_loss: 0.6823
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5578 - loss: 0.6838 - val_accuracy: 0.5840 - val_loss: 0.6820
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5566 - loss: 0.6836 - val_accuracy: 0.5832 - val_loss: 0.6817
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5560 - loss: 0.6831 - val_accuracy: 0.5824 - val_loss: 0.6814
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5601 - loss: 0.6828 - val_accuracy: 0.5816 - val_loss: 0.6811
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5597 - loss: 0.6827 - val_accuracy: 0.5808 - val_loss: 0.6808
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5572 - loss: 0.6825 - val_accuracy: 0.5840 - val_loss: 0.6806
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5580 - loss: 0.6824 - val_accuracy: 0.5816 - val_loss: 0.6803
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5544 - loss: 0.6819 - val_accuracy: 0.5824 - val_loss: 0.6801
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5601 - loss: 0.6817 - val_accuracy: 0.5816 - val_loss: 0.6798
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5591 - loss: 0.6813 - val_accuracy: 0.5816 - val_loss: 0.6795
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5597 - loss: 0.6810 - val_accuracy: 0.5816 - val_loss: 0.6792
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5572 - loss: 0.6814 - val_accuracy: 0.5824 - val_loss: 0.6789
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5625 - loss: 0.6806 - val_accuracy: 0.5808 - val_loss: 0.6786
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5601 - loss: 0.6809 - val_accuracy: 0.5816 - val_loss: 0.6784
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5560 - loss: 0.6806 - val_accuracy: 0.5816 - val_loss: 0.6782
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5615 - loss: 0.6802 - val_accuracy: 0.5808 - val_loss: 0.6779
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5605 - loss: 0.6797 - val_accuracy: 0.5816 - val_loss: 0.6776
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5585 - loss: 0.6798 - val_accuracy: 0.5816 - val_loss: 0.6773
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5625 - loss: 0.6787 - val_accuracy: 0.5832 - val_loss: 0.6769
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5632 - loss: 0.6789 - val_accuracy: 0.5848 - val_loss: 0.6765
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5603 - loss: 0.6788 - val_accuracy: 0.5865 - val_loss: 0.6762
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5634 - loss: 0.6784 - val_accuracy: 0.5881 - val_loss: 0.6760
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5660 - loss: 0.6781 - val_accuracy: 0.5905 - val_loss: 0.6756
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.5632 - loss: 0.6772 - val_accuracy: 0.5889 - val_loss: 0.6751
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5632 - loss: 0.6779 - val_accuracy: 0.5922 - val_loss: 0.6745
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5629 - loss: 0.6775 - val_accuracy: 0.5914 - val_loss: 0.6740
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.5636 - loss: 0.6766 - val_accuracy: 0.5914 - val_loss: 0.6734
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5672 - loss: 0.6761 - val_accuracy: 0.5930 - val_loss: 0.6726
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5674 - loss: 0.6753 - val_accuracy: 0.5962 - val_loss: 0.6718
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5668 - loss: 0.6745 - val_accuracy: 0.6011 - val_loss: 0.6709
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5697 - loss: 0.6736 - val_accuracy: 0.5987 - val_loss: 0.6696
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5703 - loss: 0.6732 - val_accuracy: 0.6003 - val_loss: 0.6681
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5770 - loss: 0.6714 - val_accuracy: 0.5995 - val_loss: 0.6666
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5821 - loss: 0.6694 - val_accuracy: 0.6011 - val_loss: 0.6646
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5836 - loss: 0.6673 - val_accuracy: 0.6085 - val_loss: 0.6623
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5882 - loss: 0.6651 - val_accuracy: 0.6158 - val_loss: 0.6596
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6009 - loss: 0.6630 - val_accuracy: 0.6215 - val_loss: 0.6559
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6101 - loss: 0.6595 - val_accuracy: 0.6223 - val_loss: 0.6530
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6219 - loss: 0.6547 - val_accuracy: 0.6411 - val_loss: 0.6489
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6319 - loss: 0.6535 - val_accuracy: 0.6533 - val_loss: 0.6462
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6405 - loss: 0.6503 - val_accuracy: 0.6688 - val_loss: 0.6420
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6501 - loss: 0.6465 - val_accuracy: 0.6697 - val_loss: 0.6390
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6599 - loss: 0.6424 - val_accuracy: 0.6786 - val_loss: 0.6352
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6650 - loss: 0.6391 - val_accuracy: 0.6860 - val_loss: 0.6318
#         val_acc=68.6%  AUC=0.735  F1=64.3%  κ=0.373  t=40s
# [  117] model=CNN | keep=11 | Dropped: AF3, AF4, T8
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.5036 - loss: 0.7513 - val_accuracy: 0.5033 - val_loss: 0.7249
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5034 - loss: 0.7177 - val_accuracy: 0.4984 - val_loss: 0.7035
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4974 - loss: 0.7016 - val_accuracy: 0.4869 - val_loss: 0.6948
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4836 - loss: 0.6948 - val_accuracy: 0.5065 - val_loss: 0.6919
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4974 - loss: 0.6918 - val_accuracy: 0.5245 - val_loss: 0.6912
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5103 - loss: 0.6911 - val_accuracy: 0.5481 - val_loss: 0.6910
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5179 - loss: 0.6905 - val_accuracy: 0.5457 - val_loss: 0.6908
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5205 - loss: 0.6905 - val_accuracy: 0.5546 - val_loss: 0.6906
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5291 - loss: 0.6899 - val_accuracy: 0.5571 - val_loss: 0.6903
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5244 - loss: 0.6896 - val_accuracy: 0.5579 - val_loss: 0.6899
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5279 - loss: 0.6893 - val_accuracy: 0.5555 - val_loss: 0.6895
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5336 - loss: 0.6889 - val_accuracy: 0.5644 - val_loss: 0.6892
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5319 - loss: 0.6885 - val_accuracy: 0.5595 - val_loss: 0.6888
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5283 - loss: 0.6885 - val_accuracy: 0.5604 - val_loss: 0.6884
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5354 - loss: 0.6884 - val_accuracy: 0.5628 - val_loss: 0.6881
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5370 - loss: 0.6876 - val_accuracy: 0.5677 - val_loss: 0.6878
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5370 - loss: 0.6874 - val_accuracy: 0.5677 - val_loss: 0.6874
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5395 - loss: 0.6878 - val_accuracy: 0.5677 - val_loss: 0.6870
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5432 - loss: 0.6873 - val_accuracy: 0.5693 - val_loss: 0.6867
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5452 - loss: 0.6868 - val_accuracy: 0.5669 - val_loss: 0.6863
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5440 - loss: 0.6866 - val_accuracy: 0.5677 - val_loss: 0.6860
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5468 - loss: 0.6868 - val_accuracy: 0.5701 - val_loss: 0.6856
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5454 - loss: 0.6860 - val_accuracy: 0.5710 - val_loss: 0.6853
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5493 - loss: 0.6858 - val_accuracy: 0.5669 - val_loss: 0.6849
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5513 - loss: 0.6850 - val_accuracy: 0.5669 - val_loss: 0.6846
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5523 - loss: 0.6853 - val_accuracy: 0.5628 - val_loss: 0.6843
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5523 - loss: 0.6852 - val_accuracy: 0.5628 - val_loss: 0.6840
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5554 - loss: 0.6849 - val_accuracy: 0.5669 - val_loss: 0.6838
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5562 - loss: 0.6847 - val_accuracy: 0.5661 - val_loss: 0.6835
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5564 - loss: 0.6843 - val_accuracy: 0.5669 - val_loss: 0.6832
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5597 - loss: 0.6840 - val_accuracy: 0.5677 - val_loss: 0.6829
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5576 - loss: 0.6840 - val_accuracy: 0.5677 - val_loss: 0.6826
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5566 - loss: 0.6837 - val_accuracy: 0.5677 - val_loss: 0.6823
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5605 - loss: 0.6832 - val_accuracy: 0.5693 - val_loss: 0.6820
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5578 - loss: 0.6827 - val_accuracy: 0.5701 - val_loss: 0.6816
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5617 - loss: 0.6822 - val_accuracy: 0.5710 - val_loss: 0.6812
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5642 - loss: 0.6820 - val_accuracy: 0.5710 - val_loss: 0.6807
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5597 - loss: 0.6821 - val_accuracy: 0.5718 - val_loss: 0.6802
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5617 - loss: 0.6811 - val_accuracy: 0.5726 - val_loss: 0.6797
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5619 - loss: 0.6808 - val_accuracy: 0.5750 - val_loss: 0.6791
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5627 - loss: 0.6800 - val_accuracy: 0.5750 - val_loss: 0.6783
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5664 - loss: 0.6789 - val_accuracy: 0.5759 - val_loss: 0.6774
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5701 - loss: 0.6780 - val_accuracy: 0.5767 - val_loss: 0.6762
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5772 - loss: 0.6766 - val_accuracy: 0.5824 - val_loss: 0.6748
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.5813 - loss: 0.6744 - val_accuracy: 0.5816 - val_loss: 0.6730
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5864 - loss: 0.6729 - val_accuracy: 0.5873 - val_loss: 0.6709
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5852 - loss: 0.6706 - val_accuracy: 0.5914 - val_loss: 0.6683
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6054 - loss: 0.6671 - val_accuracy: 0.5979 - val_loss: 0.6653
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6044 - loss: 0.6641 - val_accuracy: 0.6060 - val_loss: 0.6619
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6258 - loss: 0.6600 - val_accuracy: 0.6158 - val_loss: 0.6579
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6358 - loss: 0.6572 - val_accuracy: 0.6297 - val_loss: 0.6539
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6525 - loss: 0.6507 - val_accuracy: 0.6395 - val_loss: 0.6501
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6609 - loss: 0.6479 - val_accuracy: 0.6509 - val_loss: 0.6459
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6725 - loss: 0.6416 - val_accuracy: 0.6599 - val_loss: 0.6419
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6731 - loss: 0.6367 - val_accuracy: 0.6623 - val_loss: 0.6387
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6795 - loss: 0.6345 - val_accuracy: 0.6672 - val_loss: 0.6341
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6835 - loss: 0.6300 - val_accuracy: 0.6770 - val_loss: 0.6315
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6899 - loss: 0.6285 - val_accuracy: 0.6803 - val_loss: 0.6276
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6921 - loss: 0.6283 - val_accuracy: 0.6852 - val_loss: 0.6250
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6988 - loss: 0.6212 - val_accuracy: 0.6860 - val_loss: 0.6233
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6986 - loss: 0.6189 - val_accuracy: 0.6917 - val_loss: 0.6205
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7003 - loss: 0.6201 - val_accuracy: 0.6974 - val_loss: 0.6183
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7109 - loss: 0.6179 - val_accuracy: 0.7039 - val_loss: 0.6164
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7052 - loss: 0.6177 - val_accuracy: 0.7080 - val_loss: 0.6155
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7064 - loss: 0.6141 - val_accuracy: 0.7088 - val_loss: 0.6142
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7099 - loss: 0.6140 - val_accuracy: 0.7080 - val_loss: 0.6123
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7121 - loss: 0.6138 - val_accuracy: 0.7080 - val_loss: 0.6113
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7113 - loss: 0.6119 - val_accuracy: 0.7080 - val_loss: 0.6102
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7154 - loss: 0.6099 - val_accuracy: 0.7145 - val_loss: 0.6095
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7103 - loss: 0.6130 - val_accuracy: 0.7170 - val_loss: 0.6094
#         val_acc=71.7%  AUC=0.768  F1=70.3%  κ=0.434  t=39s
# [  118] model=CNN | keep=11 | Dropped: AF3, F3, F4
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.5036 - loss: 0.7590 - val_accuracy: 0.5033 - val_loss: 0.7380
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5034 - loss: 0.7207 - val_accuracy: 0.5000 - val_loss: 0.7079
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4928 - loss: 0.7026 - val_accuracy: 0.4861 - val_loss: 0.6961
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4860 - loss: 0.6953 - val_accuracy: 0.5008 - val_loss: 0.6920
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4889 - loss: 0.6916 - val_accuracy: 0.5269 - val_loss: 0.6906
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4997 - loss: 0.6907 - val_accuracy: 0.5367 - val_loss: 0.6901
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5176 - loss: 0.6901 - val_accuracy: 0.5612 - val_loss: 0.6898
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5295 - loss: 0.6899 - val_accuracy: 0.5555 - val_loss: 0.6895
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5409 - loss: 0.6894 - val_accuracy: 0.5628 - val_loss: 0.6892
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5368 - loss: 0.6892 - val_accuracy: 0.5628 - val_loss: 0.6888
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.5409 - loss: 0.6887 - val_accuracy: 0.5636 - val_loss: 0.6884
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5446 - loss: 0.6881 - val_accuracy: 0.5669 - val_loss: 0.6880
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5476 - loss: 0.6878 - val_accuracy: 0.5653 - val_loss: 0.6876
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5527 - loss: 0.6875 - val_accuracy: 0.5693 - val_loss: 0.6871
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.5511 - loss: 0.6871 - val_accuracy: 0.5767 - val_loss: 0.6866
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5556 - loss: 0.6865 - val_accuracy: 0.5799 - val_loss: 0.6861
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5560 - loss: 0.6864 - val_accuracy: 0.5775 - val_loss: 0.6856
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5560 - loss: 0.6862 - val_accuracy: 0.5750 - val_loss: 0.6851
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5636 - loss: 0.6860 - val_accuracy: 0.5759 - val_loss: 0.6846
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.5650 - loss: 0.6852 - val_accuracy: 0.5775 - val_loss: 0.6839
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5638 - loss: 0.6846 - val_accuracy: 0.5816 - val_loss: 0.6832
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5636 - loss: 0.6837 - val_accuracy: 0.5848 - val_loss: 0.6822
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5742 - loss: 0.6827 - val_accuracy: 0.5840 - val_loss: 0.6812
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5721 - loss: 0.6819 - val_accuracy: 0.5873 - val_loss: 0.6801
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5709 - loss: 0.6803 - val_accuracy: 0.5897 - val_loss: 0.6788
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5750 - loss: 0.6800 - val_accuracy: 0.5922 - val_loss: 0.6773
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.5717 - loss: 0.6782 - val_accuracy: 0.5840 - val_loss: 0.6756
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5772 - loss: 0.6773 - val_accuracy: 0.5881 - val_loss: 0.6738
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5874 - loss: 0.6743 - val_accuracy: 0.6003 - val_loss: 0.6716
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6011 - loss: 0.6729 - val_accuracy: 0.6085 - val_loss: 0.6696
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6068 - loss: 0.6704 - val_accuracy: 0.6199 - val_loss: 0.6676
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6111 - loss: 0.6675 - val_accuracy: 0.6191 - val_loss: 0.6657
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6084 - loss: 0.6661 - val_accuracy: 0.6158 - val_loss: 0.6639
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6091 - loss: 0.6645 - val_accuracy: 0.6150 - val_loss: 0.6626
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6115 - loss: 0.6613 - val_accuracy: 0.6175 - val_loss: 0.6615
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6131 - loss: 0.6603 - val_accuracy: 0.6191 - val_loss: 0.6602
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6193 - loss: 0.6586 - val_accuracy: 0.6191 - val_loss: 0.6594
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6229 - loss: 0.6562 - val_accuracy: 0.6207 - val_loss: 0.6587
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6209 - loss: 0.6539 - val_accuracy: 0.6199 - val_loss: 0.6581
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6307 - loss: 0.6515 - val_accuracy: 0.6256 - val_loss: 0.6561
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6299 - loss: 0.6511 - val_accuracy: 0.6338 - val_loss: 0.6563
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6364 - loss: 0.6482 - val_accuracy: 0.6272 - val_loss: 0.6549
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6352 - loss: 0.6473 - val_accuracy: 0.6354 - val_loss: 0.6550
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6407 - loss: 0.6459 - val_accuracy: 0.6354 - val_loss: 0.6527
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6501 - loss: 0.6438 - val_accuracy: 0.6305 - val_loss: 0.6540
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6521 - loss: 0.6417 - val_accuracy: 0.6321 - val_loss: 0.6501
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6533 - loss: 0.6389 - val_accuracy: 0.6313 - val_loss: 0.6507
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6601 - loss: 0.6382 - val_accuracy: 0.6313 - val_loss: 0.6505
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6603 - loss: 0.6373 - val_accuracy: 0.6395 - val_loss: 0.6481
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6676 - loss: 0.6340 - val_accuracy: 0.6419 - val_loss: 0.6469
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6668 - loss: 0.6352 - val_accuracy: 0.6460 - val_loss: 0.6436
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6709 - loss: 0.6325 - val_accuracy: 0.6460 - val_loss: 0.6450
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6709 - loss: 0.6326 - val_accuracy: 0.6452 - val_loss: 0.6430
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6813 - loss: 0.6278 - val_accuracy: 0.6452 - val_loss: 0.6437
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6768 - loss: 0.6261 - val_accuracy: 0.6460 - val_loss: 0.6409
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6852 - loss: 0.6272 - val_accuracy: 0.6493 - val_loss: 0.6376
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6801 - loss: 0.6249 - val_accuracy: 0.6533 - val_loss: 0.6352
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6854 - loss: 0.6246 - val_accuracy: 0.6566 - val_loss: 0.6331
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6807 - loss: 0.6230 - val_accuracy: 0.6574 - val_loss: 0.6317
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6897 - loss: 0.6202 - val_accuracy: 0.6607 - val_loss: 0.6315
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6903 - loss: 0.6197 - val_accuracy: 0.6688 - val_loss: 0.6276
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6886 - loss: 0.6190 - val_accuracy: 0.6713 - val_loss: 0.6259
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6848 - loss: 0.6210 - val_accuracy: 0.6786 - val_loss: 0.6224
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6917 - loss: 0.6175 - val_accuracy: 0.6786 - val_loss: 0.6217
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6929 - loss: 0.6153 - val_accuracy: 0.6868 - val_loss: 0.6187
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6960 - loss: 0.6182 - val_accuracy: 0.6835 - val_loss: 0.6191
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6968 - loss: 0.6151 - val_accuracy: 0.6860 - val_loss: 0.6171
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7005 - loss: 0.6137 - val_accuracy: 0.6852 - val_loss: 0.6144
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6954 - loss: 0.6116 - val_accuracy: 0.6868 - val_loss: 0.6138
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6972 - loss: 0.6075 - val_accuracy: 0.6884 - val_loss: 0.6102
#         val_acc=68.8%  AUC=0.759  F1=68.1%  κ=0.377  t=39s
# [  119] model=CNN | keep=11 | Dropped: AF3, F3, F7
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.5036 - loss: 0.7560 - val_accuracy: 0.5033 - val_loss: 0.7338
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5028 - loss: 0.7190 - val_accuracy: 0.5016 - val_loss: 0.7058
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.4903 - loss: 0.7016 - val_accuracy: 0.4837 - val_loss: 0.6950
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4819 - loss: 0.6944 - val_accuracy: 0.5033 - val_loss: 0.6913
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4899 - loss: 0.6911 - val_accuracy: 0.5204 - val_loss: 0.6901
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5072 - loss: 0.6903 - val_accuracy: 0.5375 - val_loss: 0.6895
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5238 - loss: 0.6895 - val_accuracy: 0.5653 - val_loss: 0.6890
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5287 - loss: 0.6891 - val_accuracy: 0.5759 - val_loss: 0.6884
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.5452 - loss: 0.6883 - val_accuracy: 0.5759 - val_loss: 0.6878
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.5413 - loss: 0.6881 - val_accuracy: 0.5791 - val_loss: 0.6870
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5440 - loss: 0.6874 - val_accuracy: 0.5808 - val_loss: 0.6863
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5507 - loss: 0.6867 - val_accuracy: 0.5808 - val_loss: 0.6856
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5517 - loss: 0.6860 - val_accuracy: 0.5816 - val_loss: 0.6848
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5542 - loss: 0.6861 - val_accuracy: 0.5840 - val_loss: 0.6842
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5566 - loss: 0.6853 - val_accuracy: 0.5897 - val_loss: 0.6836
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5564 - loss: 0.6847 - val_accuracy: 0.5873 - val_loss: 0.6830
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5629 - loss: 0.6844 - val_accuracy: 0.5914 - val_loss: 0.6823
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5589 - loss: 0.6841 - val_accuracy: 0.5938 - val_loss: 0.6816
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5676 - loss: 0.6839 - val_accuracy: 0.5848 - val_loss: 0.6809
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5672 - loss: 0.6829 - val_accuracy: 0.5840 - val_loss: 0.6801
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5619 - loss: 0.6822 - val_accuracy: 0.5881 - val_loss: 0.6792
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5617 - loss: 0.6818 - val_accuracy: 0.5865 - val_loss: 0.6782
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5707 - loss: 0.6801 - val_accuracy: 0.5873 - val_loss: 0.6771
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5693 - loss: 0.6791 - val_accuracy: 0.5881 - val_loss: 0.6758
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5693 - loss: 0.6774 - val_accuracy: 0.5832 - val_loss: 0.6743
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5756 - loss: 0.6771 - val_accuracy: 0.5856 - val_loss: 0.6728
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5746 - loss: 0.6750 - val_accuracy: 0.5922 - val_loss: 0.6709
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5772 - loss: 0.6744 - val_accuracy: 0.5946 - val_loss: 0.6689
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5829 - loss: 0.6713 - val_accuracy: 0.5946 - val_loss: 0.6667
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5927 - loss: 0.6695 - val_accuracy: 0.6036 - val_loss: 0.6646
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6080 - loss: 0.6665 - val_accuracy: 0.6044 - val_loss: 0.6623
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6070 - loss: 0.6639 - val_accuracy: 0.6150 - val_loss: 0.6601
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6103 - loss: 0.6622 - val_accuracy: 0.6191 - val_loss: 0.6580
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6142 - loss: 0.6598 - val_accuracy: 0.6248 - val_loss: 0.6564
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6168 - loss: 0.6572 - val_accuracy: 0.6272 - val_loss: 0.6549
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6180 - loss: 0.6556 - val_accuracy: 0.6305 - val_loss: 0.6534
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6203 - loss: 0.6538 - val_accuracy: 0.6362 - val_loss: 0.6522
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6250 - loss: 0.6520 - val_accuracy: 0.6387 - val_loss: 0.6509
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6295 - loss: 0.6492 - val_accuracy: 0.6321 - val_loss: 0.6507
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6335 - loss: 0.6471 - val_accuracy: 0.6378 - val_loss: 0.6483
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6329 - loss: 0.6474 - val_accuracy: 0.6403 - val_loss: 0.6483
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6344 - loss: 0.6449 - val_accuracy: 0.6330 - val_loss: 0.6465
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6419 - loss: 0.6440 - val_accuracy: 0.6354 - val_loss: 0.6466
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6454 - loss: 0.6434 - val_accuracy: 0.6395 - val_loss: 0.6450
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6450 - loss: 0.6412 - val_accuracy: 0.6403 - val_loss: 0.6456
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6431 - loss: 0.6409 - val_accuracy: 0.6452 - val_loss: 0.6433
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6431 - loss: 0.6394 - val_accuracy: 0.6370 - val_loss: 0.6440
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6525 - loss: 0.6368 - val_accuracy: 0.6362 - val_loss: 0.6424
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6521 - loss: 0.6373 - val_accuracy: 0.6362 - val_loss: 0.6413
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6554 - loss: 0.6347 - val_accuracy: 0.6362 - val_loss: 0.6405
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6552 - loss: 0.6366 - val_accuracy: 0.6370 - val_loss: 0.6402
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6562 - loss: 0.6360 - val_accuracy: 0.6362 - val_loss: 0.6398
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6488 - loss: 0.6359 - val_accuracy: 0.6460 - val_loss: 0.6370
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6562 - loss: 0.6325 - val_accuracy: 0.6378 - val_loss: 0.6380
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6562 - loss: 0.6312 - val_accuracy: 0.6427 - val_loss: 0.6361
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6654 - loss: 0.6319 - val_accuracy: 0.6419 - val_loss: 0.6357
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6533 - loss: 0.6323 - val_accuracy: 0.6460 - val_loss: 0.6346
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6586 - loss: 0.6311 - val_accuracy: 0.6493 - val_loss: 0.6343
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6511 - loss: 0.6298 - val_accuracy: 0.6485 - val_loss: 0.6321
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6588 - loss: 0.6299 - val_accuracy: 0.6485 - val_loss: 0.6329
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.6535 - loss: 0.6297 - val_accuracy: 0.6493 - val_loss: 0.6320
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6611 - loss: 0.6300 - val_accuracy: 0.6493 - val_loss: 0.6315
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6578 - loss: 0.6297 - val_accuracy: 0.6525 - val_loss: 0.6300
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6668 - loss: 0.6274 - val_accuracy: 0.6533 - val_loss: 0.6293
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6629 - loss: 0.6263 - val_accuracy: 0.6558 - val_loss: 0.6284
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6593 - loss: 0.6296 - val_accuracy: 0.6574 - val_loss: 0.6278
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6678 - loss: 0.6263 - val_accuracy: 0.6582 - val_loss: 0.6270
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6529 - loss: 0.6281 - val_accuracy: 0.6599 - val_loss: 0.6257
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6658 - loss: 0.6252 - val_accuracy: 0.6607 - val_loss: 0.6250
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6631 - loss: 0.6233 - val_accuracy: 0.6607 - val_loss: 0.6241
#         val_acc=66.1%  AUC=0.715  F1=65.2%  κ=0.322  t=43s
# [  120] model=CNN | keep=11 | Dropped: AF3, F3, F8
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.5036 - loss: 0.7535 - val_accuracy: 0.5033 - val_loss: 0.7377
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5013 - loss: 0.7184 - val_accuracy: 0.4976 - val_loss: 0.7076
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.4883 - loss: 0.7015 - val_accuracy: 0.4869 - val_loss: 0.6959
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.4815 - loss: 0.6945 - val_accuracy: 0.5049 - val_loss: 0.6919
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4895 - loss: 0.6912 - val_accuracy: 0.5253 - val_loss: 0.6905
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5123 - loss: 0.6903 - val_accuracy: 0.5310 - val_loss: 0.6898
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5219 - loss: 0.6894 - val_accuracy: 0.5604 - val_loss: 0.6893
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5342 - loss: 0.6894 - val_accuracy: 0.5669 - val_loss: 0.6888
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5464 - loss: 0.6883 - val_accuracy: 0.5726 - val_loss: 0.6881
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5425 - loss: 0.6879 - val_accuracy: 0.5734 - val_loss: 0.6874
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5497 - loss: 0.6875 - val_accuracy: 0.5726 - val_loss: 0.6866
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5507 - loss: 0.6865 - val_accuracy: 0.5718 - val_loss: 0.6859
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5591 - loss: 0.6858 - val_accuracy: 0.5759 - val_loss: 0.6852
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5595 - loss: 0.6858 - val_accuracy: 0.5767 - val_loss: 0.6845
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5621 - loss: 0.6854 - val_accuracy: 0.5759 - val_loss: 0.6839
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5593 - loss: 0.6845 - val_accuracy: 0.5767 - val_loss: 0.6833
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5670 - loss: 0.6841 - val_accuracy: 0.5783 - val_loss: 0.6826
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5605 - loss: 0.6840 - val_accuracy: 0.5791 - val_loss: 0.6820
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5685 - loss: 0.6834 - val_accuracy: 0.5775 - val_loss: 0.6813
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5699 - loss: 0.6824 - val_accuracy: 0.5791 - val_loss: 0.6805
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5658 - loss: 0.6818 - val_accuracy: 0.5832 - val_loss: 0.6797
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5719 - loss: 0.6815 - val_accuracy: 0.5791 - val_loss: 0.6787
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5768 - loss: 0.6795 - val_accuracy: 0.5824 - val_loss: 0.6776
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5744 - loss: 0.6786 - val_accuracy: 0.5791 - val_loss: 0.6764
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5774 - loss: 0.6765 - val_accuracy: 0.5799 - val_loss: 0.6749
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5789 - loss: 0.6763 - val_accuracy: 0.5840 - val_loss: 0.6734
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5801 - loss: 0.6741 - val_accuracy: 0.5938 - val_loss: 0.6716
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.5858 - loss: 0.6732 - val_accuracy: 0.5971 - val_loss: 0.6696
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5976 - loss: 0.6707 - val_accuracy: 0.6003 - val_loss: 0.6675
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.6003 - loss: 0.6692 - val_accuracy: 0.6052 - val_loss: 0.6656
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.6040 - loss: 0.6665 - val_accuracy: 0.6126 - val_loss: 0.6634
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6113 - loss: 0.6642 - val_accuracy: 0.6166 - val_loss: 0.6616
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6084 - loss: 0.6624 - val_accuracy: 0.6207 - val_loss: 0.6599
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6260 - loss: 0.6603 - val_accuracy: 0.6215 - val_loss: 0.6585
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6225 - loss: 0.6577 - val_accuracy: 0.6248 - val_loss: 0.6572
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6207 - loss: 0.6556 - val_accuracy: 0.6297 - val_loss: 0.6559
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6315 - loss: 0.6544 - val_accuracy: 0.6354 - val_loss: 0.6546
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6323 - loss: 0.6521 - val_accuracy: 0.6419 - val_loss: 0.6533
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6325 - loss: 0.6488 - val_accuracy: 0.6419 - val_loss: 0.6525
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6372 - loss: 0.6478 - val_accuracy: 0.6476 - val_loss: 0.6501
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6427 - loss: 0.6460 - val_accuracy: 0.6460 - val_loss: 0.6497
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6395 - loss: 0.6433 - val_accuracy: 0.6419 - val_loss: 0.6472
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6501 - loss: 0.6411 - val_accuracy: 0.6427 - val_loss: 0.6471
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6474 - loss: 0.6413 - val_accuracy: 0.6452 - val_loss: 0.6443
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6542 - loss: 0.6363 - val_accuracy: 0.6452 - val_loss: 0.6444
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6544 - loss: 0.6370 - val_accuracy: 0.6533 - val_loss: 0.6413
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6590 - loss: 0.6334 - val_accuracy: 0.6452 - val_loss: 0.6418
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6627 - loss: 0.6306 - val_accuracy: 0.6485 - val_loss: 0.6398
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6637 - loss: 0.6291 - val_accuracy: 0.6517 - val_loss: 0.6385
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6690 - loss: 0.6253 - val_accuracy: 0.6599 - val_loss: 0.6354
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6670 - loss: 0.6272 - val_accuracy: 0.6582 - val_loss: 0.6355
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6664 - loss: 0.6245 - val_accuracy: 0.6607 - val_loss: 0.6338
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6686 - loss: 0.6243 - val_accuracy: 0.6648 - val_loss: 0.6324
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6735 - loss: 0.6189 - val_accuracy: 0.6672 - val_loss: 0.6306
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6741 - loss: 0.6186 - val_accuracy: 0.6672 - val_loss: 0.6298
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6784 - loss: 0.6195 - val_accuracy: 0.6672 - val_loss: 0.6289
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6729 - loss: 0.6203 - val_accuracy: 0.6721 - val_loss: 0.6267
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.6809 - loss: 0.6169 - val_accuracy: 0.6794 - val_loss: 0.6251
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6880 - loss: 0.6158 - val_accuracy: 0.6819 - val_loss: 0.6233
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.6852 - loss: 0.6128 - val_accuracy: 0.6794 - val_loss: 0.6241
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6811 - loss: 0.6132 - val_accuracy: 0.6819 - val_loss: 0.6242
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6895 - loss: 0.6115 - val_accuracy: 0.6868 - val_loss: 0.6208
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6829 - loss: 0.6109 - val_accuracy: 0.6852 - val_loss: 0.6195
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6919 - loss: 0.6080 - val_accuracy: 0.6933 - val_loss: 0.6168
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6935 - loss: 0.6072 - val_accuracy: 0.6900 - val_loss: 0.6162
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6870 - loss: 0.6101 - val_accuracy: 0.6974 - val_loss: 0.6150
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6956 - loss: 0.6045 - val_accuracy: 0.6933 - val_loss: 0.6152
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6929 - loss: 0.6058 - val_accuracy: 0.6982 - val_loss: 0.6119
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7023 - loss: 0.6024 - val_accuracy: 0.6949 - val_loss: 0.6117
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6999 - loss: 0.5991 - val_accuracy: 0.6941 - val_loss: 0.6105
#         val_acc=69.4%  AUC=0.768  F1=64.6%  κ=0.389  t=40s
# [  121] model=CNN | keep=11 | Dropped: AF3, F3, FC5
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step - accuracy: 0.5036 - loss: 0.7508 - val_accuracy: 0.5033 - val_loss: 0.7367
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5030 - loss: 0.7175 - val_accuracy: 0.4984 - val_loss: 0.7077
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4872 - loss: 0.7014 - val_accuracy: 0.4845 - val_loss: 0.6963
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.4821 - loss: 0.6947 - val_accuracy: 0.5090 - val_loss: 0.6923
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4950 - loss: 0.6915 - val_accuracy: 0.5196 - val_loss: 0.6909
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5119 - loss: 0.6907 - val_accuracy: 0.5416 - val_loss: 0.6904
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5211 - loss: 0.6900 - val_accuracy: 0.5538 - val_loss: 0.6900
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5281 - loss: 0.6900 - val_accuracy: 0.5595 - val_loss: 0.6897
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5393 - loss: 0.6892 - val_accuracy: 0.5636 - val_loss: 0.6893
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5325 - loss: 0.6889 - val_accuracy: 0.5661 - val_loss: 0.6889
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5372 - loss: 0.6888 - val_accuracy: 0.5685 - val_loss: 0.6884
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5413 - loss: 0.6880 - val_accuracy: 0.5710 - val_loss: 0.6879
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5450 - loss: 0.6874 - val_accuracy: 0.5734 - val_loss: 0.6874
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5499 - loss: 0.6873 - val_accuracy: 0.5693 - val_loss: 0.6870
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5534 - loss: 0.6871 - val_accuracy: 0.5750 - val_loss: 0.6865
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5546 - loss: 0.6863 - val_accuracy: 0.5750 - val_loss: 0.6860
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5625 - loss: 0.6861 - val_accuracy: 0.5734 - val_loss: 0.6854
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5601 - loss: 0.6861 - val_accuracy: 0.5750 - val_loss: 0.6849
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5601 - loss: 0.6857 - val_accuracy: 0.5759 - val_loss: 0.6843
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5613 - loss: 0.6849 - val_accuracy: 0.5783 - val_loss: 0.6837
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5638 - loss: 0.6845 - val_accuracy: 0.5808 - val_loss: 0.6831
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.5674 - loss: 0.6844 - val_accuracy: 0.5824 - val_loss: 0.6824
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.5660 - loss: 0.6830 - val_accuracy: 0.5856 - val_loss: 0.6817
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5644 - loss: 0.6826 - val_accuracy: 0.5873 - val_loss: 0.6809
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5654 - loss: 0.6810 - val_accuracy: 0.5873 - val_loss: 0.6801
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5711 - loss: 0.6811 - val_accuracy: 0.5799 - val_loss: 0.6792
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.5670 - loss: 0.6801 - val_accuracy: 0.5783 - val_loss: 0.6783
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5707 - loss: 0.6794 - val_accuracy: 0.5791 - val_loss: 0.6772
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5709 - loss: 0.6784 - val_accuracy: 0.5840 - val_loss: 0.6759
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5780 - loss: 0.6773 - val_accuracy: 0.5816 - val_loss: 0.6746
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5713 - loss: 0.6757 - val_accuracy: 0.5808 - val_loss: 0.6731
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5774 - loss: 0.6745 - val_accuracy: 0.5824 - val_loss: 0.6713
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5815 - loss: 0.6728 - val_accuracy: 0.5848 - val_loss: 0.6694
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5860 - loss: 0.6704 - val_accuracy: 0.5938 - val_loss: 0.6672
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5921 - loss: 0.6682 - val_accuracy: 0.5922 - val_loss: 0.6648
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5993 - loss: 0.6656 - val_accuracy: 0.6044 - val_loss: 0.6625
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6076 - loss: 0.6644 - val_accuracy: 0.6150 - val_loss: 0.6602
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6107 - loss: 0.6618 - val_accuracy: 0.6183 - val_loss: 0.6579
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6205 - loss: 0.6591 - val_accuracy: 0.6248 - val_loss: 0.6559
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6254 - loss: 0.6580 - val_accuracy: 0.6362 - val_loss: 0.6536
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6274 - loss: 0.6557 - val_accuracy: 0.6427 - val_loss: 0.6519
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6289 - loss: 0.6526 - val_accuracy: 0.6460 - val_loss: 0.6495
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6333 - loss: 0.6499 - val_accuracy: 0.6493 - val_loss: 0.6476
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6307 - loss: 0.6497 - val_accuracy: 0.6558 - val_loss: 0.6449
# Epoch 45/70
# ...
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5746 - loss: 0.6809 - val_accuracy: 0.5946 - val_loss: 0.6782
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5685 - loss: 0.6804 - val_accuracy: 0.5954 - val_loss: 0.6778
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5756 - loss: 0.6797 - val_accuracy: 0.5987 - val_loss: 0.6775
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5772 - loss: 0.6796 - val_accuracy: 0.5971 - val_loss: 0.6771
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5772 - loss: 0.6790 - val_accuracy: 0.5979 - val_loss: 0.6767
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5797 - loss: 0.6788 - val_accuracy: 0.5995 - val_loss: 0.6763
# Epoch 39/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5807 - loss: 0.6786 - val_accuracy: 0.6011 - val_loss: 0.6759
# Epoch 40/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5776 - loss: 0.6782 - val_accuracy: 0.6028 - val_loss: 0.6755
# Epoch 41/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.5823 - loss: 0.6780 - val_accuracy: 0.6036 - val_loss: 0.6751
# Epoch 42/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5803 - loss: 0.6773 - val_accuracy: 0.6011 - val_loss: 0.6748
# Epoch 43/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5858 - loss: 0.6767 - val_accuracy: 0.6028 - val_loss: 0.6743
# Epoch 44/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5899 - loss: 0.6765 - val_accuracy: 0.6020 - val_loss: 0.6739
# Epoch 45/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5915 - loss: 0.6757 - val_accuracy: 0.6020 - val_loss: 0.6734
# Epoch 46/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5931 - loss: 0.6752 - val_accuracy: 0.6020 - val_loss: 0.6729
# Epoch 47/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5909 - loss: 0.6749 - val_accuracy: 0.5979 - val_loss: 0.6725
# Epoch 48/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5970 - loss: 0.6747 - val_accuracy: 0.5954 - val_loss: 0.6721
# Epoch 49/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5960 - loss: 0.6736 - val_accuracy: 0.5954 - val_loss: 0.6715
# Epoch 50/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5987 - loss: 0.6726 - val_accuracy: 0.5946 - val_loss: 0.6709
# Epoch 51/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5982 - loss: 0.6722 - val_accuracy: 0.5922 - val_loss: 0.6702
# Epoch 52/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6062 - loss: 0.6722 - val_accuracy: 0.6003 - val_loss: 0.6696
# Epoch 53/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6080 - loss: 0.6707 - val_accuracy: 0.6044 - val_loss: 0.6691
# Epoch 54/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6123 - loss: 0.6691 - val_accuracy: 0.6069 - val_loss: 0.6682
# Epoch 55/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6164 - loss: 0.6689 - val_accuracy: 0.6020 - val_loss: 0.6674
# Epoch 56/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6154 - loss: 0.6677 - val_accuracy: 0.6020 - val_loss: 0.6667
# Epoch 57/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6197 - loss: 0.6674 - val_accuracy: 0.5962 - val_loss: 0.6663
# Epoch 58/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6270 - loss: 0.6657 - val_accuracy: 0.6011 - val_loss: 0.6651
# Epoch 59/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6350 - loss: 0.6634 - val_accuracy: 0.6020 - val_loss: 0.6637
# Epoch 60/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.6442 - loss: 0.6624 - val_accuracy: 0.6003 - val_loss: 0.6630
# Epoch 61/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6425 - loss: 0.6598 - val_accuracy: 0.5995 - val_loss: 0.6617
# Epoch 62/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6515 - loss: 0.6590 - val_accuracy: 0.5946 - val_loss: 0.6600
# Epoch 63/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6601 - loss: 0.6556 - val_accuracy: 0.6028 - val_loss: 0.6580
# Epoch 64/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6646 - loss: 0.6546 - val_accuracy: 0.6028 - val_loss: 0.6561
# Epoch 65/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6727 - loss: 0.6508 - val_accuracy: 0.6101 - val_loss: 0.6536
# Epoch 66/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6727 - loss: 0.6498 - val_accuracy: 0.6117 - val_loss: 0.6516
# Epoch 67/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6766 - loss: 0.6465 - val_accuracy: 0.6175 - val_loss: 0.6489
# Epoch 68/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6882 - loss: 0.6444 - val_accuracy: 0.6281 - val_loss: 0.6457
# Epoch 69/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6905 - loss: 0.6426 - val_accuracy: 0.6313 - val_loss: 0.6430
# Epoch 70/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6935 - loss: 0.6371 - val_accuracy: 0.6452 - val_loss: 0.6392
#         val_acc=64.5%  AUC=0.776  F1=52.7%  κ=0.293  t=41s
# [  151] model=CNN | keep=11 | Dropped: AF3, F8, O2
# Epoch 1/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.5036 - loss: 0.7440 - val_accuracy: 0.5033 - val_loss: 0.7298
# Epoch 2/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5019 - loss: 0.7124 - val_accuracy: 0.5008 - val_loss: 0.7037
# Epoch 3/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4948 - loss: 0.6983 - val_accuracy: 0.4878 - val_loss: 0.6938
# Epoch 4/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4889 - loss: 0.6927 - val_accuracy: 0.5139 - val_loss: 0.6905
# Epoch 5/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5117 - loss: 0.6899 - val_accuracy: 0.5546 - val_loss: 0.6895
# Epoch 6/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5281 - loss: 0.6893 - val_accuracy: 0.5669 - val_loss: 0.6891
# Epoch 7/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5376 - loss: 0.6886 - val_accuracy: 0.5799 - val_loss: 0.6889
# Epoch 8/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5442 - loss: 0.6887 - val_accuracy: 0.5775 - val_loss: 0.6886
# Epoch 9/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5483 - loss: 0.6879 - val_accuracy: 0.5808 - val_loss: 0.6882
# Epoch 10/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5425 - loss: 0.6878 - val_accuracy: 0.5808 - val_loss: 0.6878
# Epoch 11/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5458 - loss: 0.6875 - val_accuracy: 0.5824 - val_loss: 0.6874
# Epoch 12/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5511 - loss: 0.6868 - val_accuracy: 0.5856 - val_loss: 0.6871
# Epoch 13/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5548 - loss: 0.6866 - val_accuracy: 0.5881 - val_loss: 0.6867
# Epoch 14/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5566 - loss: 0.6867 - val_accuracy: 0.5905 - val_loss: 0.6863
# Epoch 15/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5532 - loss: 0.6864 - val_accuracy: 0.5865 - val_loss: 0.6859
# Epoch 16/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5613 - loss: 0.6854 - val_accuracy: 0.5856 - val_loss: 0.6856
# Epoch 17/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5585 - loss: 0.6856 - val_accuracy: 0.5840 - val_loss: 0.6852
# Epoch 18/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5568 - loss: 0.6856 - val_accuracy: 0.5824 - val_loss: 0.6848
# Epoch 19/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5576 - loss: 0.6856 - val_accuracy: 0.5832 - val_loss: 0.6845
# Epoch 20/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5619 - loss: 0.6847 - val_accuracy: 0.5856 - val_loss: 0.6841
# Epoch 21/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5627 - loss: 0.6846 - val_accuracy: 0.5856 - val_loss: 0.6837
# Epoch 22/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.5636 - loss: 0.6843 - val_accuracy: 0.5881 - val_loss: 0.6833
# Epoch 23/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5689 - loss: 0.6836 - val_accuracy: 0.5914 - val_loss: 0.6829
# Epoch 24/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5658 - loss: 0.6836 - val_accuracy: 0.5914 - val_loss: 0.6824
# Epoch 25/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.5678 - loss: 0.6829 - val_accuracy: 0.5897 - val_loss: 0.6819
# Epoch 26/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.5693 - loss: 0.6827 - val_accuracy: 0.5889 - val_loss: 0.6814
# Epoch 27/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5656 - loss: 0.6822 - val_accuracy: 0.5897 - val_loss: 0.6809
# Epoch 28/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5668 - loss: 0.6823 - val_accuracy: 0.5905 - val_loss: 0.6804
# Epoch 29/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5709 - loss: 0.6811 - val_accuracy: 0.5922 - val_loss: 0.6797
# Epoch 30/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5723 - loss: 0.6815 - val_accuracy: 0.5922 - val_loss: 0.6792
# Epoch 31/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5746 - loss: 0.6809 - val_accuracy: 0.5946 - val_loss: 0.6787
# Epoch 32/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5746 - loss: 0.6796 - val_accuracy: 0.5938 - val_loss: 0.6781
# Epoch 33/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5782 - loss: 0.6798 - val_accuracy: 0.5971 - val_loss: 0.6774
# Epoch 34/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5746 - loss: 0.6791 - val_accuracy: 0.6020 - val_loss: 0.6768
# Epoch 35/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5844 - loss: 0.6780 - val_accuracy: 0.6028 - val_loss: 0.6761
# Epoch 36/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5854 - loss: 0.6773 - val_accuracy: 0.6052 - val_loss: 0.6752
# Epoch 37/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5872 - loss: 0.6766 - val_accuracy: 0.6069 - val_loss: 0.6744
# Epoch 38/70
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5946 - loss: 0.6756 - val_accuracy: 0.6085 - val_loss: 0.6735
# Epoch 39/70
#  8/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5940 - loss: 0.6772
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_583/2053050882.py in <cell line: 0>()
#      41
#      42         t0      = time.time()
# ---> 43         history = model.fit(
#      44             tf.constant(X_train), tf.constant(y_train),
#      45             epochs=EPOCHS,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     421                         shuffle=False,
#     422                     )
# --> 423                 val_logs = self.evaluate(
#     424                     x=val_x,
#     425                     y=val_y,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     509             for begin_step, end_step, iterator in epoch_iterator:
#     510                 callbacks.on_test_batch_begin(begin_step)
# --> 511                 logs = self.test_function(iterator)
#     512                 callbacks.on_test_batch_end(end_step, logs)
#     513                 if self.stop_evaluating:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Cell 6 – Save All Metrics to Excel

# %%
results_df   = pd.DataFrame(all_results)
summary_path = os.path.join(OUT_ROOT, f'{MODEL_NAME}_AllCombos_Summary.xlsx')

with pd.ExcelWriter(summary_path, engine='openpyxl') as writer:
    results_df.to_excel(writer, sheet_name='All Results', index=False)
    results_df.sort_values('val_acc', ascending=False).to_excel(
        writer, sheet_name='Sorted by Accuracy', index=False)
    results_df.sort_values('auc', ascending=False).to_excel(
        writer, sheet_name='Sorted by AUC', index=False)
    results_df.sort_values('f1', ascending=False).to_excel(
        writer, sheet_name='Sorted by F1', index=False)
    results_df.sort_values('cohen_kappa', ascending=False).to_excel(
        writer, sheet_name='Sorted by Kappa', index=False)

print(f'Summary saved → {summary_path}')
results_df.head()

# %% [markdown]
# ## Cell 7 – Summary Plots

# %%
fw, fs = 'bold', 12

# ── 7a. Box-plots: metric distribution per subset size ───────────────────────
for metric, ylabel, plot_title in [
    ('val_acc', 'Validation Accuracy (%)', 'Accuracy by Subset Size'),
    ('auc',     'AUC',                     'AUC by Subset Size'),
    ('f1',      'F1 Score (%)',            'F1 Score by Subset Size'),
]:
    grouped = [results_df.loc[results_df['n_keep'] == k, metric].values
               for k in range(1, 15)]
    fig, ax = plt.subplots(figsize=(10, 5))
    bp = ax.boxplot(grouped, patch_artist=True,
                    boxprops=dict(facecolor='#00ABCD', color='#121212'),
                    medianprops=dict(color='#FF4500', linewidth=2))
    ax.set_title(f'{MODEL_NAME} – {plot_title}', fontweight=fw, fontsize=fs)
    ax.set_xlabel('Number of Channels Kept', fontweight=fw, fontsize=fs)
    ax.set_ylabel(ylabel, fontweight=fw, fontsize=fs)
    ax.set_xticks(range(1, 15)); ax.set_xticklabels(range(1, 15), fontweight=fw)
    ax.tick_params(labelsize=fs)
    plt.tight_layout()
    out_path = os.path.join(OUT_ROOT, f'summary_boxplot_{metric}.png')
    fig.savefig(out_path, dpi=150); plt.close(fig)
    print(f'Saved: {out_path}')


# ── 7b. Top-10 by accuracy ───────────────────────────────────────────────────
top10 = results_df.sort_values('val_acc', ascending=False).head(10)
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title(f'{MODEL_NAME} – Top-10 Combinations by Validation Accuracy',
             fontweight=fw, fontsize=fs)
ax.set_xlabel('Validation Accuracy (%)', fontweight=fw, fontsize=fs)
hbars = ax.barh(range(len(top10)), top10['val_acc'].values, color='#121212')
ax.bar_label(hbars, fmt=lambda x: f'{x:.1f}%', fontsize=fs, fontweight=fw)
ax.set_yticks(range(len(top10)))
ax.set_yticklabels(top10['title'].values, fontweight=fw, fontsize=10)
ax.set_xlim(0, 110)
plt.tight_layout()
out_path = os.path.join(OUT_ROOT, 'summary_top10_accuracy.png')
fig.savefig(out_path, dpi=150); plt.close(fig)
print(f'Saved: {out_path}')


# ── 7c. Channel importance (Δ accuracy) ─────────────────────────────────────
mean_acc_with    = {}
mean_acc_without = {}
for ch in CHANNEL_NAMES:
    mean_acc_with[ch]    = results_df[results_df['kept'].str.contains(ch)]['val_acc'].mean()
    mean_acc_without[ch] = results_df[~results_df['kept'].str.contains(ch)]['val_acc'].mean()

importance_df = pd.DataFrame({
    'Channel':          CHANNEL_NAMES,
    'Mean Acc With':    [mean_acc_with[c]    for c in CHANNEL_NAMES],
    'Mean Acc Without': [mean_acc_without[c] for c in CHANNEL_NAMES],
})
importance_df['Delta'] = importance_df['Mean Acc With'] - importance_df['Mean Acc Without']
importance_df = importance_df.sort_values('Delta', ascending=True)

fig, ax = plt.subplots(figsize=(8, 6))
colors = ['#121212' if d >= 0 else '#CC0000' for d in importance_df['Delta']]
hbars = ax.barh(range(len(importance_df)), importance_df['Delta'].values, color=colors)
ax.bar_label(hbars, fmt=lambda x: f'{x:+.2f}%', fontsize=fs, fontweight=fw)
ax.set_title(f'{MODEL_NAME} – Channel Importance\n(Mean Acc with − without)',
             fontweight=fw, fontsize=fs)
ax.set_xlabel('Δ Accuracy (%)', fontweight=fw, fontsize=fs)
ax.set_yticks(range(len(importance_df)))
ax.set_yticklabels(importance_df['Channel'].values, fontweight=fw, fontsize=fs)
ax.axvline(0, color='grey', linewidth=0.8, linestyle='--')
plt.tight_layout()
out_path = os.path.join(OUT_ROOT, 'summary_channel_importance.png')
fig.savefig(out_path, dpi=150); plt.close(fig)
print(f'Saved: {out_path}')

importance_df.to_csv(os.path.join(OUT_ROOT, 'channel_importance.csv'), index=False)
print('All summary plots saved.')
importance_df.sort_values('Delta', ascending=False)

# %%
from google.colab import drive
import shutil
from google.colab import files

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Your folder path
folder_path = "/content/drive/MyDrive/thesis_works/outputs_CNN"

# Step 3: Name of output zip file (will be created in /content)
output_filename = "outputs_CNN_summary"

# Step 4: Create zip file
shutil.make_archive(output_filename, 'zip', folder_path)

# Step 5: Download zip to your computer
files.download(output_filename + ".zip")
